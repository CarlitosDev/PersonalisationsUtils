# %%
import os
import sys
import pandas as pd
import pandasql as pdsql


from bkcharts import Donut
from bokeh.io import output_notebook, show

# Do this trick to add the new Beamly functionality
pythonModsRoot = '/Users/carlos.aguilar/Google Drive/PythonDev/Coding/BeamlyPython'
if pythonModsRoot not in sys.path:
    sys.path.append(pythonModsRoot)

import redshiftSqlAlchemy as rsa
import carlosUtils        as cu
import bokehUtils         as bk

from IPython.display import Markdown, display, HTML
def printmd(string):
    display(Markdown(string))

# %%
numCampaigns = 20;
cutOffPerc   = 96.0;

# %%
# set the table and schema
schemaName = 'adform'
tableName  = 'impressionsExtended'

# set the name of the variables to break-down
breakDownKeyWords = ['campaign_id', 'yyyy_mm_dd', \
'publisher_domain', 'bannerid', 'bannerType', \
'client_id', 'device_type_id', 'placement_id_activity_id', 'tag_id', \
'city_id' ];

# flags to set the outputs
saveFigure    = True;
saveDFToExcel = True;

# %%
# connect to the Redshift box
user     = 'carlos_aguilar'
password = 'MdogDI64j6vH90g973'
dbname   = 'adform'
host     = 'adform-ops.c7dxcjhlundm.eu-central-1.redshift.amazonaws.com'

rs = rsa.RedshiftAlchemy(user=user, password=password, 
    database=dbname, host=host)

# %%
sqlQuery = '''SELECT count(*) as numRecords 
    from {}.{}'''.format(schemaName, tableName)
df = rs.query2DF(sqlQuery);
printmd('Analysing **' + schemaName + '.' + tableName + '** (' +  str(df.numrecords[0]) + ' records)' )
# Out:
# Analysing **adform.impressionsExtended** (195387010 records)

# %%
# This snippet breaks down the variables and writes the counts to a file
printmd('_Break down variables_ from ' +  schemaName +'.' + tableName)
for currentKey in breakDownKeyWords:
    sqlQuery = '''SELECT count(distinct({})) as numRecords 
        from {}.{}'''.format(currentKey, schemaName, tableName)
    df = rs.query2DF(sqlQuery);
    currentText = '**' + currentKey + '**' + ' has got **' + str(df.numrecords[0]) + '** unique values...'
    printmd(currentText)
# Out:
# _Break down variables_ from adform.impressionsExtended
# **campaign_id** has got **247** unique values...
# **yyyy_mm_dd** has got **66** unique values...
# **publisher_domain** has got **276148** unique values...
# **bannerid** has got **1454** unique values...
# **bannerType** has got **4** unique values...
# **client_id** has got **37** unique values...
# **device_type_id** has got **5** unique values...
# **placement_id_activity_id** has got **1636** unique values...
# **tag_id** has got **3091** unique values...
# **city_id** has got **220894** unique values...

# %%
# This bit takes the 'numCampaigns' most clicked campaigns and writes the results

sqlQuery = '''SELECT
A.campaign_id,
A.clientsname,
A.countryname,
A.devicename,
A.startdate,
A.enddate,
sum(A.numRecords) as totalImpressions,
B.numTotals
from adform.impressionsExtended as A
inner join (
  SELECT  campaign_id,
  sum(numRecords) AS numTotals,
  rank() over (order by numTotals desc) as rnk
  from adform.impressionsExtended
  group by 1
) as B
on A.campaign_id = B.campaign_id
where B.rnk <= {}
group by 1,2,3,4,5,6,B.numTotals
order by numTotals DESC'''.format(numCampaigns)


df        = rs.query2DF(sqlQuery)
groupedDF = df.groupby(df['campaign_id'])
idx       = 0;


# Get a list of the most clicked campaigns
vars2show = ['campaign_id', 'clientsname', 'numtotals', 'startdate', 'enddate']
df2 = df[vars2show].copy()
df2.drop_duplicates(inplace=True)
display(df2)
# Out:
#       campaign_id       clientsname  numtotals              startdate  \
# 0          897248         CoverGirl  104971036  2017-05-15 00:00:00.0
# 358        886811      Sally Hansen   48491511  2017-04-25 00:00:00.0
# 746        929928  Clairol Consumer   41799226  2017-06-15 00:00:00.0
# 1480       886100      Sally Hansen   41189281  2017-04-17 00:00:00.0
# 2177       886095      Sally Hansen   32643950  2017-05-01 00:00:00.0
# 2856       888329      Sally Hansen   32176714  2017-05-08 00:00:00.0
# 3269       894699            Rimmel   30504815  2017-05-10 00:00:00.0
# 3833       912694  OPI Professional   28922186  2017-06-01 00:00:00.0
# 4545       886846      Sally Hansen   20148263  2017-05-08 00:00:00.0
# 5266       903883            Rimmel   19277041  2017-05-18 00:00:00.0
# 5831       923338            Rimmel   17903269  2017-06-07 00:00:00.0
# 6502       907580      Calvin Klein   17698973  2017-05-19 00:00:00.0
# 6955       930891  OPI Professional   15421693  2017-06-16 00:00:00.0
# 7641       904136  Clairol Consumer   15178309  2017-05-22 00:00:00.0
# 7769       875443        Philosophy   14802201  2017-04-06 00:00:00.0
# 8062       930443       Marc Jacobs   13943022  2017-06-14 00:00:00.0
# 8472       930412            Adidas   13745391  2017-06-08 00:00:00.0
# 8572       923742         CoverGirl   13220398  2017-06-01 00:00:00.0
# 8822       941709      Sally Hansen   13191594  2017-07-05 00:00:00.0
# 9499       916730      Calvin Klein   12781501  2017-05-30 00:00:00.0
#
#                     enddate
# 0     2017-06-30 23:59:00.0
# 358   2017-06-30 23:59:00.0
# 746   2017-06-30 23:59:00.0
# 1480  2017-06-30 23:59:00.0
# 2177  2017-06-30 23:59:00.0
# 2856  2017-06-30 23:59:00.0
# 3269  2017-06-06 23:59:00.0
# 3833  2017-06-30 23:59:00.0
# 4545  2017-06-30 23:59:00.0
# 5266  2017-06-10 23:59:00.0
# 5831  2017-06-30 23:59:00.0
# 6502  2017-06-25 23:59:00.0
# 6955  2017-06-30 23:59:00.0
# 7641  2017-06-30 23:59:00.0
# 7769  2017-06-30 23:59:00.0
# 8062  2017-06-28 23:59:00.0
# 8472  2017-06-30 23:59:00.0
# 8572  2017-06-25 23:59:00.0
# 8822  2017-07-31 23:59:00.0
# 9499  2017-06-25 23:59:00.0

# %%
for name, group in groupedDF:
    idx += 1;
    groupClientName = group['clientsname'].iloc[0]
    cu.printf('{} - Processing {} id {}...'.format(idx, groupClientName, name))
    print('Current campaign {} id {} got {} impressions'.format(groupClientName, \
        name, group['totalimpressions'].sum()))
    
    # Get the percentage for the break down
    totalCampaignClicks = group['totalimpressions'].sum();
    group['perct'] = 100.0*group['totalimpressions']/totalCampaignClicks;
    group.sort_values(['perct'], ascending=[0], inplace = True)
    
    # cutoff at 96%
    idx95p = group['perct'].cumsum() < cutOffPerc
    df95p  = group.loc[idx95p, :]

    fileName  = groupClientName + ' (id ' + str(name) + ').xlsx'
    

    display(df95p)

    # bokeh
    title  = groupClientName + \
        ' (id ' + str(name) + ') clicks: ' + str(totalCampaignClicks)
    labels = ['devicename','countryname']
    values = 'totalimpressions'
    hoverText ='totalimpressions'
    textFontSize = '10pt'

    donutChart = Donut(df95p, label=labels, values=values,
    text_font_size=textFontSize, hover_text=hoverText,
    title=title)
    output_notebook()
    show(donutChart)
# Out:
# Current campaign Philosophy id 875443 got 14802201 impressions
# 21 - Processing Philosophy id 875443...
# /Users/carlos.aguilar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/carlos.aguilar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#       campaign_id clientsname    countryname          devicename  \
# 7859       875443  Philosophy  United States              Mobile
# 7968       875443  Philosophy  United States  Desktop and Laptop
#
#                   startdate                enddate  totalimpressions  \
# 7859  2017-04-06 00:00:00.0  2017-06-30 23:59:00.0           7137526
# 7968  2017-04-06 00:00:00.0  2017-06-30 23:59:00.0           4150401
#
#       numtotals      perct
# 7859   14802201  48.219356
# 7968   14802201  28.039080
# /Users/carlos.aguilar/anaconda3/lib/python3.6/site-packages/bkcharts/builders/donut_builder.py:118: PerformanceWarning: indexing past lexsort depth may impact performance.
#   chart = create_and_build(DonutBuilder, data, **kw)
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1e8dc5d2-9bb1-413a-bf31-48ce18f6474f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="33770c77-c668-4348-b83c-5ba4fbf1c0a2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("33770c77-c668-4348-b83c-5ba4fbf1c0a2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("33770c77-c668-4348-b83c-5ba4fbf1c0a2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '33770c77-c668-4348-b83c-5ba4fbf1c0a2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"73e92235-fdf1-4a80-8c2e-c364de8a2194":{"roots":{"references":[{"attributes":{"axis_label":null,"formatter":{"id":"de56f975-f833-4601-96a7-a194d357d45d","type":"BasicTickFormatter"},"plot":{"id":"46d60b61-8951-4b93-9a81-5424e5f51a0e","subtype":"Chart","type":"Plot"},"ticker":{"id":"430a9f38-c6eb-4650-b8d7-b17e6cea8fad","type":"BasicTicker"},"visible":false},"id":"4b701025-66eb-498c-a232-0d492b93914d","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["end","level","start","values","inners","outers","centers","color","devicename_countryname"],"data":{"centers":{"__ndarray__":"AAAAAAAA8j8AAAAAAADyPwAAAAAAAAJAAAAAAAAAAkA=","dtype":"float64","shape":[4]},"color":["#f22c40","#5ab738","#f22c40","#5ab738"],"devicename_countryname":[["Desktop and Laptop",""],["Mobile",""],["Desktop and Laptop","United States"],["Mobile","United States"]],"end":{"__ndarray__":"rSQ6Tlt7AkAYLURU+yEZQK0kOk5bewJAGC1EVPshGUA=","dtype":"float64","shape":[4]},"inners":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAPg/AAAAAAAA+D8=","dtype":"float64","shape":[4]},"level":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAPA/AAAAAAAA8D8=","dtype":"float64","shape":[4]},"outers":{"__ndarray__":"AAAAAAAA+D8AAAAAAAD4PwAAAAAAAAhAAAAAAAAACEA=","dtype":"float64","shape":[4]},"start":{"__ndarray__":"AAAAAAAAAACtJDpOW3sCQAAAAAAAAAAArSQ6Tlt7AkA=","dtype":"float64","shape":[4]},"values":[4150401,7137526,4150401,7137526]}},"id":"8515d11f-35ac-4a28-8bda-ae77196a46ca","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"46d60b61-8951-4b93-9a81-5424e5f51a0e","subtype":"Chart","type":"Plot"}},"id":"47aaa2aa-fe58-4ff2-809a-ec54a76cc5d1","type":"WheelZoomTool"},{"attributes":{},"id":"430a9f38-c6eb-4650-b8d7-b17e6cea8fad","type":"BasicTicker"},{"attributes":{"callback":null,"plot":{"id":"46d60b61-8951-4b93-9a81-5424e5f51a0e","subtype":"Chart","type":"Plot"},"tooltips":[["Totalimpressions","@values"]]},"id":"4cebdefd-d48c-4b6c-a62d-66d828ce54aa","type":"HoverTool"},{"attributes":{},"id":"b9a2e621-feae-4210-9f9f-30ba4b28ecd4","type":"LinearScale"},{"attributes":{"plot":{"id":"46d60b61-8951-4b93-9a81-5424e5f51a0e","subtype":"Chart","type":"Plot"}},"id":"b8d993db-5de7-4274-bc8c-9af351072396","type":"PanTool"},{"attributes":{},"id":"7486629b-8f70-4735-9254-479e15e98c92","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["text","x","y","text_angle"],"data":{"text":["Desktop and Laptop","Mobile","United States","United States"],"text_angle":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAK0kOk5be/I/Q7bSJ9LAHUA=","dtype":"float64","shape":[4]},"x":[0.4542885835446934,-0.4542885835446937,0.9085771670893869,-0.9085771670893874],"y":[1.029197203096159,-1.0291972030961587,2.058394406192318,-2.0583944061923174]}},"id":"e8a9fe4b-7725-4b88-b34f-a1667758d751","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":3.1500000000000004,"start":-3.1500000000000004},"id":"c465fab0-b353-4125-b81d-151d553b5bb2","type":"Range1d"},{"attributes":{"plot":{"id":"46d60b61-8951-4b93-9a81-5424e5f51a0e","subtype":"Chart","type":"Plot"}},"id":"1fb02f67-c5f5-4d09-8cae-aa16768dc06d","type":"HelpTool"},{"attributes":{"plot":{"id":"46d60b61-8951-4b93-9a81-5424e5f51a0e","subtype":"Chart","type":"Plot"}},"id":"698189a5-a9f1-411d-a6f2-792aa36d6450","type":"ResetTool"},{"attributes":{},"id":"0ffbc46d-4055-4795-93b8-162815be08c5","type":"BasicTickFormatter"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":"88727a31-6acf-423d-b309-b9262ea81996","type":"AnnularWedge"},{"attributes":{"location":"top_left","plot":{"id":"46d60b61-8951-4b93-9a81-5424e5f51a0e","subtype":"Chart","type":"Plot"}},"id":"ac2b99c9-9a66-444e-bd21-009a33fe5576","type":"Legend"},{"attributes":{},"id":"6b943687-2258-4abe-9d9 ...
# 22 - Processing Sally Hansen id 886095...
# Current campaign Sally Hansen id 886095 got 32643950 impressions
#       campaign_id   clientsname    countryname          devicename  \
# 2399       886095  Sally Hansen  United States  Desktop and Laptop
# 2178       886095  Sally Hansen  United States              Mobile
#
#                   startdate                enddate  totalimpressions  \
# 2399  2017-05-01 00:00:00.0  2017-06-30 23:59:00.0          15548496
# 2178  2017-05-01 00:00:00.0  2017-06-30 23:59:00.0          14955756
#
#       numtotals      perct
# 2399   32643950  47.630559
# 2178   32643950  45.814787
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="34796bbb-ee51-47bd-8ad8-b6dd8f784200">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="646ab9e3-9d86-40a6-beb4-764bc703bc05"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("646ab9e3-9d86-40a6-beb4-764bc703bc05");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("646ab9e3-9d86-40a6-beb4-764bc703bc05");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '646ab9e3-9d86-40a6-beb4-764bc703bc05' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2047d160-b9fb-4cd1-a2aa-91e8c3d38823":{"roots":{"references":[{"attributes":{"callback":null,"end":3.1500000000000004,"start":-3.1500000000000004},"id":"a0bbf076-4d7f-451c-b086-46b4ad0f3df2","type":"Range1d"},{"attributes":{"plot":{"id":"1b767e1f-d5ab-4a45-bf2c-28734a35cf30","subtype":"Chart","type":"Plot"}},"id":"7f70603d-dba5-49d1-a26f-490c62e57ed6","type":"HelpTool"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":"54dccf69-5df5-4270-aecd-80286baafb3a","type":"AnnularWedge"},{"attributes":{"callback":null,"end":3.1500000000000004,"start":-3.1500000000000004},"id":"622ee804-271e-4d70-a415-11727f960833","type":"Range1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"05967c3f-b994-4e68-ac11-8b917d5c5550","type":"PanTool"},{"id":"35f5a510-81fd-4ff3-8fee-19e8d9843146","type":"WheelZoomTool"},{"id":"4aa8c869-947b-4128-bd3f-6a2dc3626352","type":"BoxZoomTool"},{"id":"90ab7989-150c-4d8c-bf58-955443b2808e","type":"SaveTool"},{"id":"e7018514-99c6-4de7-b6c2-c0b7dcbd8fa9","type":"ResetTool"},{"id":"7f70603d-dba5-49d1-a26f-490c62e57ed6","type":"HelpTool"},{"id":"f86e6f37-079e-4d44-9ed1-75fc5ffd5b72","type":"HoverTool"}]},"id":"4b7d06a5-6b34-47f3-a774-ba11acb503f0","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"44e1a66f-835b-4564-aa19-2be928d6dacb","type":"BoxAnnotation"},{"attributes":{"angle":{"field":"text_angle","units":"rad"},"text_align":"center","text_baseline":"middle","text_font_size":{"value":"10pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"66a1b111-4edf-4b7e-bc92-d630aa50b18f","type":"Text"},{"attributes":{},"id":"9d0a7844-0dd5-46e9-a13b-273d000e791a","type":"LinearScale"},{"attributes":{},"id":"e416bbf0-6d6f-45e0-8ad0-eb52659bfc33","type":"BasicTickFormatter"},{"attributes":{},"id":"7ff6d898-7a60-4908-b9da-20025cd5b48f","type":"BasicTickFormatter"},{"attributes":{"axis_label":null,"formatter":{"id":"7ff6d898-7a60-4908-b9da-20025cd5b48f","type":"BasicTickFormatter"},"plot":{"id":"1b767e1f-d5ab-4a45-bf2c-28734a35cf30","subtype":"Chart","type":"Plot"},"ticker":{"id":"b5d866fc-070f-4900-b3a1-bb141211d911","type":"BasicTicker"},"visible":false},"id":"8e29ebf9-148b-4f9a-be6a-a15f9603ff43","type":"LinearAxis"},{"attributes":{"axis_label":null,"formatter":{"id":"e416bbf0-6d6f-45e0-8ad0-eb52659bfc33","type":"BasicTickFormatter"},"plot":{"id":"1b767e1f-d5ab-4a45-bf2c-28734a35cf30","subtype":"Chart","type":"Plot"},"ticker":{"id":"faab3d17-f387-4955-93c8-c9fbe28988bf","type":"BasicTicker"},"visible":false},"id":"31ac58bc-98cf-49b6-8eea-b733a794abee","type":"LinearAxis"},{"attributes":{"plot":{"id":"1b767e1f-d5ab-4a45-bf2c-28734a35cf30","subtype":"Chart","type":"Plot"}},"id":"90ab7989-150c-4d8c-bf58-955443b2808e","type":"SaveTool"},{"attributes":{"data_source":{"id":"b51df0ed-1452-4d01-9ec1-640f94c138e3","type":"ColumnDataSource"},"glyph":{"id":"66a1b111-4edf-4b7e-bc92-d630aa50b18f","type":"Text"},"hover_glyph":null,"muted_glyph":null},"id":"872674e1-e9dc-431a-b94b-6f674d3fdf79","type":"GlyphRenderer"},{"attributes":{},"id":"faab3d17-f387-4955-93c8-c9fbe28988bf","type":"BasicTicker"},{"attributes":{"callback":null,"plot":{"id":"1b767e1f-d5ab-4a45-bf2c-28734a35cf30","subtype":"Chart","type":"Plot"},"tooltips":[["Totalimpressions","@values"]]},"id":"f86e6f37-079e-4d44-9ed1-75fc5ffd5b72","type":"HoverTool"},{"attributes":{"data_source":{"id":"9a474601-ff80-4791-a99b-bc51d4c8 ...
# Current campaign Sally Hansen id 886100 got 41189281 impressions
# 23 - Processing Sally Hansen id 886100...
#       campaign_id   clientsname    countryname          devicename  \
# 1480       886100  Sally Hansen  United States              Mobile
# 1481       886100  Sally Hansen  United States  Desktop and Laptop
#
#                   startdate                enddate  totalimpressions  \
# 1480  2017-04-17 00:00:00.0  2017-06-30 23:59:00.0          21400058
# 1481  2017-04-17 00:00:00.0  2017-06-30 23:59:00.0          17076200
#
#       numtotals      perct
# 1480   41189281  51.955406
# 1481   41189281  41.457873
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fb4451f9-9b99-4368-8d8a-0b2fb5403e91">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="024523cb-40b2-4d88-84f7-16ae66ab1f73"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("024523cb-40b2-4d88-84f7-16ae66ab1f73");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("024523cb-40b2-4d88-84f7-16ae66ab1f73");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '024523cb-40b2-4d88-84f7-16ae66ab1f73' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"490779be-98b5-41fc-afee-618fb3436ca7":{"roots":{"references":[{"attributes":{},"id":"14be9287-adba-4d29-86fc-f8dc067ec3a0","type":"ToolEvents"},{"attributes":{"plot":{"id":"81233ed1-7631-4ac1-8c60-0a3b44c190bd","subtype":"Chart","type":"Plot"}},"id":"54ac8a21-0895-478b-99bc-382b2e69cbe4","type":"SaveTool"},{"attributes":{"below":[{"id":"84a41f75-6ffa-492f-9d32-a9f5943bb407","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"06efcf15-4725-40a6-a4fa-6e953cbad4dc","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"1188ce89-88f0-4a3b-b844-807ae434d8cc","type":"BoxAnnotation"},{"id":"41ae2aca-33ff-4102-b4fd-f42b52e9514a","type":"GlyphRenderer"},{"id":"279b9058-869f-457b-9bcf-6d1e68e3abd3","type":"GlyphRenderer"},{"id":"aae0656c-61b7-43f0-82aa-d36f0e2df710","type":"Legend"},{"id":"84a41f75-6ffa-492f-9d32-a9f5943bb407","type":"LinearAxis"},{"id":"06efcf15-4725-40a6-a4fa-6e953cbad4dc","type":"LinearAxis"}],"title":{"id":"fc1a29c9-086f-4ebe-af5c-96a16cd7b223","type":"Title"},"tool_events":{"id":"14be9287-adba-4d29-86fc-f8dc067ec3a0","type":"ToolEvents"},"toolbar":{"id":"52919c43-31bb-46bf-bdd5-d878b20abb4e","type":"Toolbar"},"x_range":{"id":"03e5f57a-acd6-4321-8063-1f4608181083","type":"Range1d"},"x_scale":{"id":"8e6bd8a2-14f4-4a23-9f5b-60c90d1abf6d","type":"LinearScale"},"y_range":{"id":"abc3658f-ab98-47e1-8205-7ac0309cc88e","type":"Range1d"},"y_scale":{"id":"15425f61-12d7-44fc-8bd0-0851ab75ea36","type":"LinearScale"}},"id":"81233ed1-7631-4ac1-8c60-0a3b44c190bd","subtype":"Chart","type":"Plot"},{"attributes":{"plot":{"id":"81233ed1-7631-4ac1-8c60-0a3b44c190bd","subtype":"Chart","type":"Plot"}},"id":"746abe19-cb32-4e93-a693-f98a1475208e","type":"HelpTool"},{"attributes":{},"id":"ee85164a-2bb1-404f-b097-188ea80d7b65","type":"BasicTicker"},{"attributes":{"plot":{"id":"81233ed1-7631-4ac1-8c60-0a3b44c190bd","subtype":"Chart","type":"Plot"}},"id":"9fdd7509-6d07-4699-aba8-e48918d4566b","type":"WheelZoomTool"},{"attributes":{"axis_label":null,"formatter":{"id":"ab6dc187-ec43-4e1a-aada-fd26c0f68b49","type":"BasicTickFormatter"},"plot":{"id":"81233ed1-7631-4ac1-8c60-0a3b44c190bd","subtype":"Chart","type":"Plot"},"ticker":{"id":"f8b441e7-7911-4838-9e6f-55ab721c481d","type":"BasicTicker"},"visible":false},"id":"84a41f75-6ffa-492f-9d32-a9f5943bb407","type":"LinearAxis"},{"attributes":{"axis_label":null,"formatter":{"id":"83acb81a-278d-40d4-99a6-d86082d66d37","type":"BasicTickFormatter"},"plot":{"id":"81233ed1-7631-4ac1-8c60-0a3b44c190bd","subtype":"Chart","type":"Plot"},"ticker":{"id":"ee85164a-2bb1-404f-b097-188ea80d7b65","type":"BasicTicker"},"visible":false},"id":"06efcf15-4725-40a6-a4fa-6e953cbad4dc","type":"LinearAxis"},{"attributes":{"plot":null,"text":"Sally Hansen (id 886100) clicks: 41189281"},"id":"fc1a29c9-086f-4ebe-af5c-96a16cd7b223","type":"Title"},{"attributes":{"data_source":{"id":"5f63548d-7d71-4834-a440-a97ebacea33a","type":"ColumnDataSource"},"glyph":{"id":"ed11cd45-3946-4342-83e3-2d31a0aa80d7","type":"Text"},"hover_glyph":null,"muted_glyph":null},"id":"279b9058-869f-457b-9bcf-6d1e68e3abd3","type":"GlyphRenderer"},{"attributes":{"callback":null,"plot":{"id":"81233ed1-7631-4ac1-8c60-0a3b44c190bd","subtype":"Chart","type":"Plot"},"tooltips":[["Totalimpressions","@values"]]},"id":"583bc02e-084a-4a7c-8865-4a5926c8874d","type":"HoverTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1188ce89-88f0-4a3b-b844-807ae434d8cc","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"be584da0-1875-4565-bcc9-1e40d6c543bb","type":"ColumnDataSource"},"glyph":{"id":"fadfd511-9627-480f-ba25-53ba80ffddb4","type":"AnnularWedge"},"hover_glyph":null,"muted_glyph":null},"id":"41ae2aca-33ff-4102-b4fd-f42b52e9514a", ...
# Current campaign Sally Hansen id 886811 got 48491511 impressions
# 24 - Processing Sally Hansen id 886811...
#      campaign_id   clientsname    countryname          devicename  \
# 485       886811  Sally Hansen  United States              Mobile
# 490       886811  Sally Hansen  United States  Desktop and Laptop
#
#                  startdate                enddate  totalimpressions  \
# 485  2017-04-25 00:00:00.0  2017-06-30 23:59:00.0          35971633
# 490  2017-04-25 00:00:00.0  2017-06-30 23:59:00.0           9822559
#
#      numtotals      perct
# 485   48491511  74.181299
# 490   48491511  20.256244
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5b0389fc-cf73-494c-bbca-138f9602b96b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e030d153-ce9f-4605-a839-e982edea1542"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e030d153-ce9f-4605-a839-e982edea1542");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e030d153-ce9f-4605-a839-e982edea1542");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e030d153-ce9f-4605-a839-e982edea1542' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5fa6d650-d6f4-4778-89be-0f687bb334be":{"roots":{"references":[{"attributes":{"below":[{"id":"78e93f71-bcd8-48a5-8ebc-ea97ec5f62fe","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"abf9cc88-ddab-4a0d-a775-8298d576fad9","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"7ec6bd59-770c-4bb0-8476-08132b3af423","type":"BoxAnnotation"},{"id":"d9bf9c10-f8c8-4477-9592-39513138d0c7","type":"GlyphRenderer"},{"id":"dc92befc-c262-41c6-a05e-4b2aefb66f2b","type":"GlyphRenderer"},{"id":"24806218-d9a6-4dfd-ab86-62d8e0ce13fd","type":"Legend"},{"id":"78e93f71-bcd8-48a5-8ebc-ea97ec5f62fe","type":"LinearAxis"},{"id":"abf9cc88-ddab-4a0d-a775-8298d576fad9","type":"LinearAxis"}],"title":{"id":"76b83aaf-ef0b-4632-811f-06b50908809d","type":"Title"},"tool_events":{"id":"9e3d351c-e41f-49ed-87da-aa35eb6fd589","type":"ToolEvents"},"toolbar":{"id":"082b2683-cd03-4020-adfb-ab817d98a046","type":"Toolbar"},"x_range":{"id":"4f24176d-9c2d-448d-b8f8-210b07039410","type":"Range1d"},"x_scale":{"id":"2ed811e0-e5b3-46b2-939e-a1b4b1daac79","type":"LinearScale"},"y_range":{"id":"544b333e-7d3e-496f-965b-99b76bbebc8c","type":"Range1d"},"y_scale":{"id":"be8e869e-5bfb-4646-8743-39b281101a1a","type":"LinearScale"}},"id":"3bf23647-a0a8-4ee1-936e-af7801d3af53","subtype":"Chart","type":"Plot"},{"attributes":{"axis_label":null,"formatter":{"id":"f7912bb3-1fac-43a7-9474-2ff78ba9da2c","type":"BasicTickFormatter"},"plot":{"id":"3bf23647-a0a8-4ee1-936e-af7801d3af53","subtype":"Chart","type":"Plot"},"ticker":{"id":"59038af4-0060-4b40-9fae-667b79eb95e8","type":"BasicTicker"},"visible":false},"id":"abf9cc88-ddab-4a0d-a775-8298d576fad9","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9299c100-4673-47ea-84be-257fb25b37f8","type":"PanTool"},{"id":"ca8088be-a6c3-4481-a6a7-8d24388d8e1f","type":"WheelZoomTool"},{"id":"bb600102-0e9d-4cf8-9dac-fca27d995c1f","type":"BoxZoomTool"},{"id":"f1927a04-e4eb-43f2-9a9d-2e2d63af9225","type":"SaveTool"},{"id":"5293ce72-d8f2-469e-bba0-f77ba614c99c","type":"ResetTool"},{"id":"334a9e24-c741-4901-a98f-203e4557286c","type":"HelpTool"},{"id":"80d4b6a7-0574-4364-b494-6dcb5fa547a5","type":"HoverTool"}]},"id":"082b2683-cd03-4020-adfb-ab817d98a046","type":"Toolbar"},{"attributes":{},"id":"f7912bb3-1fac-43a7-9474-2ff78ba9da2c","type":"BasicTickFormatter"},{"attributes":{"axis_label":null,"formatter":{"id":"f4bd4d5d-b150-458f-a5ec-def9240decb8","type":"BasicTickFormatter"},"plot":{"id":"3bf23647-a0a8-4ee1-936e-af7801d3af53","subtype":"Chart","type":"Plot"},"ticker":{"id":"66636ac0-b70b-46d2-869f-28411fb8a55f","type":"BasicTicker"},"visible":false},"id":"78e93f71-bcd8-48a5-8ebc-ea97ec5f62fe","type":"LinearAxis"},{"attributes":{},"id":"66636ac0-b70b-46d2-869f-28411fb8a55f","type":"BasicTicker"},{"attributes":{"location":"top_left","plot":{"id":"3bf23647-a0a8-4ee1-936e-af7801d3af53","subtype":"Chart","type":"Plot"}},"id":"24806218-d9a6-4dfd-ab86-62d8e0ce13fd","type":"Legend"},{"attributes":{"callback":null,"column_names":["end","level","start","values","inners","outers","centers","color","devicename_countryname"],"data":{"centers":{"__ndarray__":"AAAAAAAA8j8AAAAAAADyPwAAAAAAAAJAAAAAAAAAAkA=","dtype":"float64","shape":[4]},"color":["#f22c40","#5ab738","#f22c40","#5ab738"],"devicename_countryname":[["Desktop and Laptop",""],["Mobile",""],["Desktop and Laptop","United States"],["Mobile","United States"]],"end":{"__ndarray__":"yISiwTCQ9T8YLURU+yEZQMiEosEwkPU/GC1EVPshGUA=","dtype":"float64","shape":[4]},"inners":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAPg/AAAAAAAA+D8=","dtype":"float64","shape":[4]},"level":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAPA/AAAAAAAA8D8=","dtype":"float64","shape":[4]},"outers":{"__ndarray__":"AAAAAAAA+D8AAAAAAAD4PwAAAAAAAAhAAAAAAAAACEA=","dtype":"float64","shape":[4]},"start":{"__ndarray__":"AAAAAAAAAADIhKLBMJD1PwAAAAAAAAAAyISiwTCQ9T8=","dtype":"float64","shape":[4]},"values":[9822559,35 ...
# Current campaign Sally Hansen id 886846 got 20148263 impressions
# 25 - Processing Sally Hansen id 886846...
#       campaign_id   clientsname    countryname          devicename  \
# 4546       886846  Sally Hansen  United States  Desktop and Laptop
# 5034       886846  Sally Hansen  United States              Mobile
# 4548       886846  Sally Hansen  United States              Tablet
#
#                   startdate                enddate  totalimpressions  \
# 4546  2017-05-08 00:00:00.0  2017-06-30 23:59:00.0           7828394
# 5034  2017-05-08 00:00:00.0  2017-06-30 23:59:00.0           4461811
# 4548  2017-05-08 00:00:00.0  2017-06-30 23:59:00.0           4121387
#
#       numtotals      perct
# 4546   20148263  38.853940
# 5034   20148263  22.144892
# 4548   20148263  20.455297
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="eb9671e9-b64d-42dc-8808-4f2fff6b76b8">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="624da133-c44e-48e5-b9f7-a748005d485c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("624da133-c44e-48e5-b9f7-a748005d485c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("624da133-c44e-48e5-b9f7-a748005d485c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '624da133-c44e-48e5-b9f7-a748005d485c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1c52f2b7-729b-43fb-be95-abeb8dada0ab":{"roots":{"references":[{"attributes":{"axis_label":null,"formatter":{"id":"eca0942a-22cb-4575-9158-9eed7246c0f0","type":"BasicTickFormatter"},"plot":{"id":"24005431-8a44-4947-88f6-b69d37649e36","subtype":"Chart","type":"Plot"},"ticker":{"id":"4439743f-1ddf-425f-bb1a-27695dea3e46","type":"BasicTicker"},"visible":false},"id":"523db0bd-ed4c-4f92-a729-98e436ed3cc3","type":"LinearAxis"},{"attributes":{"plot":null,"text":"Sally Hansen (id 886846) clicks: 20148263"},"id":"fbb8d3c4-b72d-4f7a-a9d1-a5d0ecb631ae","type":"Title"},{"attributes":{"callback":null,"column_names":["end","level","start","values","inners","outers","centers","color","devicename_countryname"],"data":{"centers":{"__ndarray__":"AAAAAAAA8j8AAAAAAADyPwAAAAAAAPI/AAAAAAAAAkAAAAAAAAACQAAAAAAAAAJA","dtype":"float64","shape":[6]},"color":["#f22c40","#5ab738","#407ee7","#f22c40","#5ab738","#407ee7"],"devicename_countryname":[["Desktop and Laptop",""],["Mobile",""],["Tablet",""],["Desktop and Laptop","United States"],["Mobile","United States"],["Tablet","United States"]],"end":{"__ndarray__":"MDThuhH6B0BzIKPnPNISQBgtRFT7IRlAMDThuhH6B0BzIKPnPNISQBgtRFT7IRlA","dtype":"float64","shape":[6]},"inners":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA+D8AAAAAAAD4PwAAAAAAAPg/","dtype":"float64","shape":[6]},"level":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA/","dtype":"float64","shape":[6]},"outers":{"__ndarray__":"AAAAAAAA+D8AAAAAAAD4PwAAAAAAAPg/AAAAAAAACEAAAAAAAAAIQAAAAAAAAAhA","dtype":"float64","shape":[6]},"start":{"__ndarray__":"AAAAAAAAAAAwNOG6EfoHQHMgo+c80hJAAAAAAAAAAAAwNOG6EfoHQHMgo+c80hJA","dtype":"float64","shape":[6]},"values":[7828394,4461811,4121387,7828394,4461811,4121387]}},"id":"4ae05cb4-e4b6-453a-9596-fac0fbf68aca","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":3.1500000000000004,"start":-3.1500000000000004},"id":"44bb530d-8e5e-4286-aec6-233aebfac451","type":"Range1d"},{"attributes":{"callback":null,"column_names":["text","x","y","text_angle"],"data":{"text":["Desktop and Laptop","Mobile","Tablet","United States","United States","United States"],"text_angle":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAMDThuhH69z/S86uMoPgbQMam8x0c+hVA","dtype":"float64","shape":[6]},"x":[0.08120411439845535,-0.8534396362227825,0.7926746875460676,0.1624082287969107,-1.706879272445565,1.5853493750921352],"y":[1.122065457896625,-0.7329841658070961,-0.7983056054693239,2.24413091579325,-1.4659683316141923,-1.5966112109386479]}},"id":"72d3ba91-132d-4bc3-8b59-1c853793779e","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"24005431-8a44-4947-88f6-b69d37649e36","subtype":"Chart","type":"Plot"}},"id":"1d721a2e-bcbd-4d4b-9481-c54b88affa0b","type":"SaveTool"},{"attributes":{"callback":null,"plot":{"id":"24005431-8a44-4947-88f6-b69d37649e36","subtype":"Chart","type":"Plot"},"tooltips":[["Totalimpressions","@values"]]},"id":"fcfff404-bddc-4ddd-b479-6c035d1afd4d","type":"HoverTool"},{"attributes":{},"id":"2559921b-ac25-4726-a765-13a1769bece1","type":"ToolEvents"},{"attributes":{},"id":"95e8991c-6b0e-4de8-96f5-b9c421778f38","type":"LinearScale"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":"16a732d4-216c-4919-9be4-03fd5a886048","type":"AnnularWedge"},{"attributes":{},"id":"24fd459b-745a-432c-9d92-0337f9c97127","type":"LinearScale"},{"attributes":{},"id":"eca0942a-22cb-4575-9158-9eed7246c0f0","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":3.1500000000000004,"start":-3.1500000000000004},"id":"5d39cc9e-ece2-4024-b822-75201459cff9","type":"Range1d"},{"attributes":{"angle":{"field":"text_angle","units":"rad"},"text_align":"center","text_baseline":"middle","text_font_size ...
# Current campaign Sally Hansen id 888329 got 32176714 impressions
# 26 - Processing Sally Hansen id 888329...
#       campaign_id   clientsname    countryname          devicename  \
# 2999       888329  Sally Hansen  United States  Desktop and Laptop
# 2856       888329  Sally Hansen  United States              Mobile
# 3001       888329  Sally Hansen  United States              Tablet
#
#                   startdate                enddate  totalimpressions  \
# 2999  2017-05-08 00:00:00.0  2017-06-30 23:59:00.0          11152329
# 2856  2017-05-08 00:00:00.0  2017-06-30 23:59:00.0           8609426
# 3001  2017-05-08 00:00:00.0  2017-06-30 23:59:00.0           6913464
#
#       numtotals      perct
# 2999   32176714  34.659627
# 2856   32176714  26.756697
# 3001   32176714  21.485923
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="eec95110-147c-4089-9dc5-cd6ba9711c16">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="12ac8a7b-39e5-46d0-9d35-86f4c7acf665"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("12ac8a7b-39e5-46d0-9d35-86f4c7acf665");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("12ac8a7b-39e5-46d0-9d35-86f4c7acf665");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '12ac8a7b-39e5-46d0-9d35-86f4c7acf665' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
# ...
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1a486b53-e15c-454c-b353-ae99e50bfe85");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1a486b53-e15c-454c-b353-ae99e50bfe85");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1a486b53-e15c-454c-b353-ae99e50bfe85' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"88fa72cc-f83d-4150-a111-3cf11b566139":{"roots":{"references":[{"attributes":{},"id":"7a4243f6-0c2f-418d-95fd-0b9bdd547f5f","type":"BasicTicker"},{"attributes":{"axis_label":null,"formatter":{"id":"91da4966-b7f6-40e7-8e6b-c2a9be40324f","type":"BasicTickFormatter"},"plot":{"id":"05531682-6838-4eb4-a72a-0405cf313862","subtype":"Chart","type":"Plot"},"ticker":{"id":"7a4243f6-0c2f-418d-95fd-0b9bdd547f5f","type":"BasicTicker"},"visible":false},"id":"c4ceccc2-61d9-4fbc-bc77-729d5a240f9c","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"55d0d61e-4538-479c-acd9-c3c21b44a651","type":"PanTool"},{"id":"fde4d63c-235f-4c13-8634-bdd77e8b1874","type":"WheelZoomTool"},{"id":"a62914d5-90d2-4ff5-8499-f0fbe8c21f8a","type":"BoxZoomTool"},{"id":"8a51c355-4f0b-4fe0-b04c-891f094a12f8","type":"SaveTool"},{"id":"b7cb17d2-b363-4283-8af8-4b08278332bc","type":"ResetTool"},{"id":"de0a7b14-2235-4a21-a68f-648cacd1b816","type":"HelpTool"},{"id":"14d2ee61-d088-48b4-bcca-b87c35053cb4","type":"HoverTool"}]},"id":"ea824be9-b1dd-409d-9eb1-96c61c26715f","type":"Toolbar"},{"attributes":{},"id":"aff5ac27-5efb-495d-9f5f-5611ae6acf5e","type":"LinearScale"},{"attributes":{"callback":null,"column_names":["end","level","start","values","inners","outers","centers","color","devicename_countryname"],"data":{"centers":{"__ndarray__":"AAAAAAAA8j8AAAAAAADyPwAAAAAAAPI/AAAAAAAAAkAAAAAAAAACQAAAAAAAAAJA","dtype":"float64","shape":[6]},"color":["#f22c40","#5ab738","#407ee7","#f22c40","#5ab738","#407ee7"],"devicename_countryname":[["Mobile",""],["Tablet",""],["Unknown",""],["Mobile","United Kingdom"],["Tablet","United Kingdom"],["Unknown","United Kingdom"]],"end":{"__ndarray__":"Lh8rnOCkFUAlBpKTGrMXQBgtRFT7IRlALh8rnOCkFUAlBpKTGrMXQBgtRFT7IRlA","dtype":"float64","shape":[6]},"inners":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA+D8AAAAAAAD4PwAAAAAAAPg/","dtype":"float64","shape":[6]},"level":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA/","dtype":"float64","shape":[6]},"outers":{"__ndarray__":"AAAAAAAA+D8AAAAAAAD4PwAAAAAAAPg/AAAAAAAACEAAAAAAAAAIQAAAAAAAAAhA","dtype":"float64","shape":[6]},"start":{"__ndarray__":"AAAAAAAAAAAuHyuc4KQVQCUGkpMasxdAAAAAAAAAAAAuHyuc4KQVQCUGkpMasxdA","dtype":"float64","shape":[6]},"values":[12702134,1206343,841046,12702134,1206343,841046]}},"id":"a0497964-8a1b-46d2-8336-6cff5fbcef0f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"6fb14958-0060-44b1-8d04-9111b2f86581","type":"ColumnDataSource"},"glyph":{"id":"77154a1e-9711-41b6-85a4-a1b0d297cc45","type":"Text"},"hover_glyph":null,"muted_glyph":null},"id":"6e4dbd9e-4224-464b-8eca-112da763c96a","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"05531682-6838-4eb4-a72a-0405cf313862","subtype":"Chart","type":"Plot"}},"id":"8a51c355-4f0b-4fe0-b04c-891f094a12f8","type":"SaveTool"},{"attributes":{"location":"top_left","plot":{"id":"05531682-6838-4eb4-a72a-0405cf313862","subtype":"Chart","type":"Plot"}},"id":"d8303028-2566-4849-bb76-d8c2dc11e98e","type":"Legend"},{"attributes":{"data_source":{"id":"a0497964-8a1b-46d2-8336-6cff5fbcef0f","type":"ColumnDataSource"},"glyph":{"id":"d78087e5-db46-46a3-b6c3-462e8931f232","type":"AnnularWedge"},"hover_glyph":null,"muted_glyph":null},"id":"4687f97a-df32-4556-8a8d-1a09bbf42435","type":"GlyphRenderer"},{"attributes":{"angle":{"field":"text_angle","units":"rad"},"text_align":"center","text_baseline":"middle","text_font_size":{"value":"10pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"77154a1e-9711-41b6-85a4-a1b0d297cc45","type":"Text"},{"attributes":{"axis_label":null,"formatter":{"id":"3662521d-fdd5-40a2-b808-87ba7a7ec545","type":"BasicTickFormatter"},"plot":{"id":"05531682-6838-4eb4-a72a-0405cf313862","subtype":"Chart","type":"Plot"},"ticker":{"id":"8c74c83f-3e13-4c1e-9b8d-edf46611ee53","type":"BasicTicker"},"visible":false},"id":"e52b3d1f-b0ec-46dd-a460-4bd0f9e934a7","type":"LinearAxis"},{"attri ...
# Current campaign Sally Hansen id 941709 got 13191594 impressions
# 40 - Processing Sally Hansen id 941709...
#       campaign_id   clientsname     countryname          devicename  \
# 9296       941709  Sally Hansen   United States              Mobile
# 9273       941709  Sally Hansen   United States  Desktop and Laptop
# 9038       941709  Sally Hansen   United States              Tablet
# 9050       941709  Sally Hansen  United Kingdom  Desktop and Laptop
# 9040       941709  Sally Hansen            None  Desktop and Laptop
# 9060       941709  Sally Hansen       Australia  Desktop and Laptop
# 9042       941709  Sally Hansen   United States             Unknown
# 9275       941709  Sally Hansen            None              Mobile
# 8822       941709  Sally Hansen          Canada  Desktop and Laptop
#
#                   startdate                enddate  totalimpressions  \
# 9296  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0           7022252
# 9273  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0           4616102
# 9038  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0            587140
# 9050  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0            108721
# 9040  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0             71935
# 9060  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0             71579
# 9042  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0             65791
# 9275  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0             60808
# 8822  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0             41573
#
#       numtotals      perct
# 9296   13191594  53.232778
# 9273   13191594  34.992754
# 9038   13191594   4.450865
# 9050   13191594   0.824169
# 9040   13191594   0.545309
# 9060   13191594   0.542611
# 9042   13191594   0.498734
# 9275   13191594   0.460960
# 8822   13191594   0.315148
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="69e189cf-161f-4caa-a136-66cd93c9bd90">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="028506da-946e-4303-83e9-4d35d2168383"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("028506da-946e-4303-83e9-4d35d2168383");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("028506da-946e-4303-83e9-4d35d2168383");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '028506da-946e-4303-83e9-4d35d2168383' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ad89eb18-e8b6-4f83-8a48-d1b5ae4e4a26":{"roots":{"references":[{"attributes":{"below":[{"id":"7d161a2e-c069-4a10-8b50-7b48a17ba3e3","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"2c92fee9-1831-489d-ad06-d9910322997d","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"7163436a-607b-4ee7-aeb6-811005ab3cf1","type":"BoxAnnotation"},{"id":"7e857f82-9e4e-4489-b29f-4b716576c327","type":"GlyphRenderer"},{"id":"c2f3de2a-5b95-4cbb-af19-6922cd10f6b9","type":"GlyphRenderer"},{"id":"8f39cb46-bbc4-43fc-a727-c7de436b3cb3","type":"Legend"},{"id":"7d161a2e-c069-4a10-8b50-7b48a17ba3e3","type":"LinearAxis"},{"id":"2c92fee9-1831-489d-ad06-d9910322997d","type":"LinearAxis"}],"title":{"id":"a75c80e1-3935-4ffc-bffc-ae2b90607e52","type":"Title"},"tool_events":{"id":"6d16807b-7252-4a15-9603-f38a145b0a45","type":"ToolEvents"},"toolbar":{"id":"5a6ebf9e-acdf-406e-8bbe-cee3c4e15f3e","type":"Toolbar"},"x_range":{"id":"c82d876b-b97d-4f42-ac0d-5edfc7de7b80","type":"Range1d"},"x_scale":{"id":"b9c0faea-195d-4cc0-ac0f-bd55b74bf235","type":"LinearScale"},"y_range":{"id":"965b9357-b903-4388-be24-7edcc4814933","type":"Range1d"},"y_scale":{"id":"8560d117-9c22-4d90-aeec-35407c9da709","type":"LinearScale"}},"id":"bd3af230-f171-451a-a64a-41fbebd01f4b","subtype":"Chart","type":"Plot"},{"attributes":{"location":"top_left","plot":{"id":"bd3af230-f171-451a-a64a-41fbebd01f4b","subtype":"Chart","type":"Plot"}},"id":"8f39cb46-bbc4-43fc-a727-c7de436b3cb3","type":"Legend"},{"attributes":{"plot":{"id":"bd3af230-f171-451a-a64a-41fbebd01f4b","subtype":"Chart","type":"Plot"}},"id":"41f6860d-fb86-478e-bc64-3807de844008","type":"SaveTool"},{"attributes":{"plot":{"id":"bd3af230-f171-451a-a64a-41fbebd01f4b","subtype":"Chart","type":"Plot"}},"id":"d418dc4e-d56e-4985-892a-494de8b0385e","type":"PanTool"},{"attributes":{"callback":null,"plot":{"id":"bd3af230-f171-451a-a64a-41fbebd01f4b","subtype":"Chart","type":"Plot"},"tooltips":[["Totalimpressions","@values"]]},"id":"2fc2b46c-e30d-4f9f-8280-71873cd769b8","type":"HoverTool"},{"attributes":{"data_source":{"id":"4ebc71fa-e145-49bd-af0b-ee8db6ebdc1d","type":"ColumnDataSource"},"glyph":{"id":"6f67b14d-da14-4efc-921b-8bc0ef9c1262","type":"Text"},"hover_glyph":null,"muted_glyph":null},"id":"c2f3de2a-5b95-4cbb-af19-6922cd10f6b9","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["end","level","start","values","inners","outers","centers","color","devicename_countryname"],"data":{"centers":{"__ndarray__":"AAAAAAAA8j8AAAAAAADyPwAAAAAAAPI/AAAAAAAA8j8AAAAAAAACQAAAAAAAAAJAAAAAAAAAAkAAAAAAAAACQAAAAAAAAAJAAAAAAAAAAkAAAAAAAAACQA==","dtype":"float64","shape":[11]},"color":["#f22c40","#5ab738","#407ee7","#df5320","#f22c40","#f22c40","#f22c40","#f22c40","#5ab738","#407ee7","#df5320"],"devicename_countryname":[["Desktop and Laptop",""],["Mobile",""],["Tablet",""],["Unknown",""],["Desktop and Laptop","Australia"],["Desktop and Laptop","Canada"],["Desktop and Laptop","United Kingdom"],["Desktop and Laptop","United States"],["Mobile","United States"],["Tablet","United States"],["Unknown","United States"]],"end":{"__ndarray__":"yk9M0iCEA0DqWveTyNUXQLFeJzSCABlAGC1EVPshGUD6pVt/z3qiPzvTVLV1Nq0/NvYAWgikvD/LT0zSIIQDQOpa95PI1RdAsV4nNIIAGUAYLURU+yEZQA==","dtype":"float64","shape":[11]},"inners":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAD4PwAAAAAAAPg/AAAAAAAA+D8AAAAAAAD4PwAAAAAAAPg/AAAAAAAA+D8AAAAAAAD4Pw==","dtype":"float64","shape":[11]},"level":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAADwPwAAAAAAAPA/AAAAAAAA8D8AAAAAAADwPwAAAAAAAPA/AAAAAAAA8D8AAAAAAADwPw==","dtype":"float64","shape":[11]},"outers":{"__ndarray__":"AAAAAAAA+D8AAAAAAAD4PwAAAAAAAPg/AAAAAAAA+D8AAAAAAAAIQAAAAAAAAAhAAAAAAAAACEAAAAAAAAAIQAAAAAAAAAhAAAAAAAAACEAAAAAAAAAIQA==","dtype":"float64","shape":[11]},"start":{"__ndarray__":"AAAAAAAAAADKT0zSIIQDQOpa95PI1RdAsV4nNIIAGUAAAAAAAAAAAPqlW3/PeqI/O9NUtXU2rT829gBaCKS8P8tPTNIghANA6lr3k8jVF0CxXic0ggAZQA==","dtype":"float64","shape":[11]} ...

# %%
rs.close()
