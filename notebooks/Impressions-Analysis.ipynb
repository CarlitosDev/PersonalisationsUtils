# %%
import os
import sys
import pandas as pd
import pandasql as pdsql


from bkcharts import Donut
from bokeh.io import output_notebook, show

# Do this trick to add the new Beamly functionality
pythonModsRoot = '/Users/carlos.aguilar/Google Drive/PythonDev/Coding/BeamlyPython'
if pythonModsRoot not in sys.path:
    sys.path.append(pythonModsRoot)

import redshiftSqlAlchemy as rsa
import carlosUtils        as cu
import bokehUtils         as bk

from IPython.display import Markdown, display, HTML
def printmd(string):
    display(Markdown(string))

# %%
numCampaigns = 20;
cutOffPerc   = 96.0;

# %%
# set the table and schema
schemaName = 'adform'
tableName  = 'impressionsExtended'

# set the name of the variables to break-down
breakDownKeyWords = ['campaign_id', 'yyyy_mm_dd', \
'publisher_domain', 'bannerid', 'bannerType', \
'client_id', 'device_type_id', 'placement_id_activity_id', 'tag_id', \
'city_id' ];

# flags to set the outputs
saveFigure    = True;
saveDFToExcel = True;

# %%
# connect to the Redshift box
user     = 'carlos_aguilar'
password = 'MdogDI64j6vH90g973'
dbname   = 'adform'
host     = 'adform-ops.c7dxcjhlundm.eu-central-1.redshift.amazonaws.com'

rs = rsa.RedshiftAlchemy(user=user, password=password, 
    database=dbname, host=host)

# %%
sqlQuery = '''SELECT count(*) as numRecords 
    from {}.{}'''.format(schemaName, tableName)
df = rs.query2DF(sqlQuery);
printmd('Analysing **' + schemaName + '.' + tableName + '** (' +  str(df.numrecords[0]) + ' records)' )
# Out:
# Analysing **adform.impressionsExtended** (195387010 records)

# %%
# This snippet breaks down the variables and writes the counts to a file
printmd('_Break down variables_ from ' +  schemaName +'.' + tableName)
for currentKey in breakDownKeyWords:
    sqlQuery = '''SELECT count(distinct({})) as numRecords 
        from {}.{}'''.format(currentKey, schemaName, tableName)
    df = rs.query2DF(sqlQuery);
    currentText = '**' + currentKey + '**' + ' has got **' + str(df.numrecords[0]) + '** unique values...'
    printmd(currentText)
# Out:
# _Break down variables_ from adform.impressionsExtended
# **campaign_id** has got **247** unique values...
# **yyyy_mm_dd** has got **66** unique values...
# **publisher_domain** has got **276148** unique values...
# **bannerid** has got **1454** unique values...
# **bannerType** has got **4** unique values...
# **client_id** has got **37** unique values...
# **device_type_id** has got **5** unique values...
# **placement_id_activity_id** has got **1636** unique values...
# **tag_id** has got **3091** unique values...
# **city_id** has got **220894** unique values...

# %%
# This bit takes the 'numCampaigns' most clicked campaigns and writes the results

sqlQuery = '''SELECT
A.campaign_id,
A.clientsname,
A.countryname,
A.devicename,
A.startdate,
A.enddate,
sum(A.numRecords) as totalImpressions,
B.numTotals
from adform.impressionsExtended as A
inner join (
  SELECT  campaign_id,
  sum(numRecords) AS numTotals,
  rank() over (order by numTotals desc) as rnk
  from adform.impressionsExtended
  group by 1
) as B
on A.campaign_id = B.campaign_id
where B.rnk <= {}
group by 1,2,3,4,5,6,B.numTotals
order by numTotals DESC'''.format(numCampaigns)


df        = rs.query2DF(sqlQuery)
groupedDF = df.groupby(df['campaign_id'])
idx       = 0;


# Get a list of the most clicked campaigns
vars2show = ['campaign_id', 'clientsname', 'numtotals', 'startdate', 'enddate']
df2 = df[vars2show].copy()
df2.drop_duplicates(inplace=True)
display(df2)
# Out:
#       campaign_id       clientsname  numtotals              startdate  \
# 0          897248         CoverGirl  104971036  2017-05-15 00:00:00.0
# 358        886811      Sally Hansen   48491511  2017-04-25 00:00:00.0
# 746        929928  Clairol Consumer   41799226  2017-06-15 00:00:00.0
# 1480       886100      Sally Hansen   41189281  2017-04-17 00:00:00.0
# 2177       886095      Sally Hansen   32643950  2017-05-01 00:00:00.0
# 2856       888329      Sally Hansen   32176714  2017-05-08 00:00:00.0
# 3269       894699            Rimmel   30504815  2017-05-10 00:00:00.0
# 3833       912694  OPI Professional   28922186  2017-06-01 00:00:00.0
# 4545       886846      Sally Hansen   20148263  2017-05-08 00:00:00.0
# 5266       903883            Rimmel   19277041  2017-05-18 00:00:00.0
# 5831       923338            Rimmel   17903269  2017-06-07 00:00:00.0
# 6502       907580      Calvin Klein   17698973  2017-05-19 00:00:00.0
# 6955       930891  OPI Professional   15421693  2017-06-16 00:00:00.0
# 7641       904136  Clairol Consumer   15178309  2017-05-22 00:00:00.0
# 7769       875443        Philosophy   14802201  2017-04-06 00:00:00.0
# 8062       930443       Marc Jacobs   13943022  2017-06-14 00:00:00.0
# 8472       930412            Adidas   13745391  2017-06-08 00:00:00.0
# 8572       923742         CoverGirl   13220398  2017-06-01 00:00:00.0
# 8822       941709      Sally Hansen   13191594  2017-07-05 00:00:00.0
# 9499       916730      Calvin Klein   12781501  2017-05-30 00:00:00.0
#
#                     enddate
# 0     2017-06-30 23:59:00.0
# 358   2017-06-30 23:59:00.0
# 746   2017-06-30 23:59:00.0
# 1480  2017-06-30 23:59:00.0
# 2177  2017-06-30 23:59:00.0
# 2856  2017-06-30 23:59:00.0
# 3269  2017-06-06 23:59:00.0
# 3833  2017-06-30 23:59:00.0
# 4545  2017-06-30 23:59:00.0
# 5266  2017-06-10 23:59:00.0
# 5831  2017-06-30 23:59:00.0
# 6502  2017-06-25 23:59:00.0
# 6955  2017-06-30 23:59:00.0
# 7641  2017-06-30 23:59:00.0
# 7769  2017-06-30 23:59:00.0
# 8062  2017-06-28 23:59:00.0
# 8472  2017-06-30 23:59:00.0
# 8572  2017-06-25 23:59:00.0
# 8822  2017-07-31 23:59:00.0
# 9499  2017-06-25 23:59:00.0

# %%
for name, group in groupedDF:
    idx += 1;
    groupClientName = group['clientsname'].iloc[0]
    cu.printf('{} - Processing {} id {}...'.format(idx, groupClientName, name))
    print('Current campaign {} id {} got {} impressions'.format(groupClientName, \
        name, group['totalimpressions'].sum()))
    
    # Get the percentage for the break down
    totalCampaignClicks = group['totalimpressions'].sum();
    group['perct'] = 100.0*group['totalimpressions']/totalCampaignClicks;
    group.sort_values(['perct'], ascending=[0], inplace = True)
    
    # cutoff at 96%
    idx95p = group['perct'].cumsum() < cutOffPerc
    df95p  = group.loc[idx95p, :]

    fileName  = groupClientName + ' (id ' + str(name) + ').xlsx'
    

    display(df95p)

    # bokeh
    title  = groupClientName + \
        ' (id ' + str(name) + ') clicks: ' + str(totalCampaignClicks)
    labels = ['devicename','countryname']
    values = 'totalimpressions'
    hoverText ='totalimpressions'
    textFontSize = '10pt'

    donutChart = Donut(df95p, label=labels, values=values,
    text_font_size=textFontSize, hover_text=hoverText,
    title=title)
    output_notebook()
    show(donutChart)
# Out:
# Current campaign Philosophy id 875443 got 14802201 impressions
# 1 - Processing Philosophy id 875443...
# /Users/carlos.aguilar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/carlos.aguilar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#       campaign_id clientsname    countryname          devicename  \
# 7859       875443  Philosophy  United States              Mobile
# 7968       875443  Philosophy  United States  Desktop and Laptop
#
#                   startdate                enddate  totalimpressions  \
# 7859  2017-04-06 00:00:00.0  2017-06-30 23:59:00.0           7137526
# 7968  2017-04-06 00:00:00.0  2017-06-30 23:59:00.0           4150401
#
#       numtotals      perct
# 7859   14802201  48.219356
# 7968   14802201  28.039080
# /Users/carlos.aguilar/anaconda3/lib/python3.6/site-packages/bkcharts/builders/donut_builder.py:118: PerformanceWarning: indexing past lexsort depth may impact performance.
#   chart = create_and_build(DonutBuilder, data, **kw)
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="24f8d789-81e1-4eb9-9ced-cda700915b2e">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a636eb41-0c7d-404e-9246-850cdc115387"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a636eb41-0c7d-404e-9246-850cdc115387");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a636eb41-0c7d-404e-9246-850cdc115387");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a636eb41-0c7d-404e-9246-850cdc115387' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5dc0da75-65af-4c31-ba32-c98daec2749c":{"roots":{"references":[{"attributes":{},"id":"dfdde7cd-b787-47bb-9c57-55ec9923db49","type":"BasicTickFormatter"},{"attributes":{"location":"top_left","plot":{"id":"935b591d-fb87-4cd9-a412-35d19315070a","subtype":"Chart","type":"Plot"}},"id":"548fe197-1b2d-4e1b-a77f-209c06a57fa3","type":"Legend"},{"attributes":{"plot":{"id":"935b591d-fb87-4cd9-a412-35d19315070a","subtype":"Chart","type":"Plot"}},"id":"07b645e0-139a-4df9-9c91-34c31c728677","type":"ResetTool"},{"attributes":{"plot":{"id":"935b591d-fb87-4cd9-a412-35d19315070a","subtype":"Chart","type":"Plot"}},"id":"bd4ec960-41d1-485a-b2a6-dc5f052f9520","type":"SaveTool"},{"attributes":{"below":[{"id":"4bc7db42-6be2-4393-98f1-b5059fa19360","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"ffa6582f-83c4-462c-a951-8c55daa8862b","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"83b4ea19-3336-4f6c-b64c-738192897fa8","type":"BoxAnnotation"},{"id":"376c1a29-ad46-4ebc-916c-7b093b58f7c2","type":"GlyphRenderer"},{"id":"731b9350-b81c-4dae-ba46-916f98523345","type":"GlyphRenderer"},{"id":"548fe197-1b2d-4e1b-a77f-209c06a57fa3","type":"Legend"},{"id":"4bc7db42-6be2-4393-98f1-b5059fa19360","type":"LinearAxis"},{"id":"ffa6582f-83c4-462c-a951-8c55daa8862b","type":"LinearAxis"}],"title":{"id":"cc88faba-5b8b-4e44-92f5-ccd4a0e42141","type":"Title"},"tool_events":{"id":"db6310f2-318a-42a0-9cbc-e5481bed27dc","type":"ToolEvents"},"toolbar":{"id":"a286dbec-4b82-4d46-a97d-fc1609ba5462","type":"Toolbar"},"x_range":{"id":"2c91e725-9560-47b9-b1ef-141d67128c10","type":"Range1d"},"x_scale":{"id":"a4d1c9cc-3cd2-42cd-a2f1-395a7e99b4f7","type":"LinearScale"},"y_range":{"id":"63c845e7-a103-4dff-9fc1-0546cfb963de","type":"Range1d"},"y_scale":{"id":"49ae0c3c-0ffb-4442-be16-bdeefdd26fcb","type":"LinearScale"}},"id":"935b591d-fb87-4cd9-a412-35d19315070a","subtype":"Chart","type":"Plot"},{"attributes":{"angle":{"field":"text_angle","units":"rad"},"text_align":"center","text_baseline":"middle","text_font_size":{"value":"10pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"82e9216a-d603-4cef-b18d-41bad6332f81","type":"Text"},{"attributes":{"plot":{"id":"935b591d-fb87-4cd9-a412-35d19315070a","subtype":"Chart","type":"Plot"}},"id":"11577aa0-3435-443d-8087-279ed9fac1f1","type":"PanTool"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":"5f5b4cbf-6ce5-4284-ad5d-1128df815fae","type":"AnnularWedge"},{"attributes":{},"id":"49ae0c3c-0ffb-4442-be16-bdeefdd26fcb","type":"LinearScale"},{"attributes":{"callback":null,"plot":{"id":"935b591d-fb87-4cd9-a412-35d19315070a","subtype":"Chart","type":"Plot"},"tooltips":[["Totalimpressions","@values"]]},"id":"76b312c5-b879-4d6f-bdc4-58fac48da7d4","type":"HoverTool"},{"attributes":{},"id":"5c052f84-8523-49b6-bbe2-78238841adbb","type":"BasicTicker"},{"attributes":{},"id":"a4d1c9cc-3cd2-42cd-a2f1-395a7e99b4f7","type":"LinearScale"},{"attributes":{"callback":null,"end":3.1500000000000004,"start":-3.1500000000000004},"id":"2c91e725-9560-47b9-b1ef-141d67128c10","type":"Range1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"11577aa0-3435-443d-8087-279ed9fac1f1","type":"PanTool"},{"id":"6b52c852-601c-4a23-aeac-c27f0ea93a9b","type":"WheelZoomTool"},{"id":"3327d7e3-398e-47a8-9597-73dcfdb86ce0","type":"BoxZoomTool"},{"id":"bd4ec960-41d1-485a-b2a6-dc5f052f9520","type":"SaveTool"},{"id":"07b645e0-139a-4df9-9c91-34c31c728677","type":"ResetTool"},{"id":"5a65883e-39c3-47de-a6df-4f41036a2c60","type":"HelpTool"},{"id":"76b312c5-b879-4d6f-bdc4-58fac48da7d4","type":"HoverTool"}]},"id":"a286dbec-4b82-4d46-a97d-fc1609ba5462","type":"Toolbar"},{"attributes":{"callback": ...
# Current campaign Sally Hansen id 886095 got 32643950 impressions
# 2 - Processing Sally Hansen id 886095...
#       campaign_id   clientsname    countryname          devicename  \
# 2399       886095  Sally Hansen  United States  Desktop and Laptop
# 2178       886095  Sally Hansen  United States              Mobile
#
#                   startdate                enddate  totalimpressions  \
# 2399  2017-05-01 00:00:00.0  2017-06-30 23:59:00.0          15548496
# 2178  2017-05-01 00:00:00.0  2017-06-30 23:59:00.0          14955756
#
#       numtotals      perct
# 2399   32643950  47.630559
# 2178   32643950  45.814787
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f5ca0f8a-eb1b-48c1-b490-280bc69f329c">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4baaefd9-3620-4634-99b7-aaae8d99a650"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4baaefd9-3620-4634-99b7-aaae8d99a650");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4baaefd9-3620-4634-99b7-aaae8d99a650");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4baaefd9-3620-4634-99b7-aaae8d99a650' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f020d2df-8f84-4368-8f00-7d380abcf1bb":{"roots":{"references":[{"attributes":{"plot":null,"text":"Sally Hansen (id 886095) clicks: 32643950"},"id":"a219dc88-666c-4d1a-8338-f239c7e1148b","type":"Title"},{"attributes":{"overlay":{"id":"a7824a45-db56-4b38-b166-32be922b5384","type":"BoxAnnotation"},"plot":{"id":"7c38a5c4-94c1-4692-8397-18df5ad0fe88","subtype":"Chart","type":"Plot"}},"id":"1e8fdeab-1ebd-47b6-88c6-1b3cf74403ff","type":"BoxZoomTool"},{"attributes":{"location":"top_left","plot":{"id":
},"outers":{"__ndarray__":"AAAAAAAA+D8AAAAAAAD4PwAAAAAAAPg/AAAAAAAACEAAAAAAAAAIQAAAAAAAAAhA","dtype":"float64","shape":[6]},"start":{"__ndarray__":"AAAAAAAAAAAuHyuc4KQVQCUGkpMasxdAAAAAAAAAAAAuHyuc4KQVQCUGkpMasxdA","dtype":"float64","shape":[6]},"values":[12702134,1206343,841046,12702134,1206343,841046]}},"id":"232345c6-33c6-4bd8-8e4b-946e2816bf5c","type":"ColumnDataSource"},{"attributes":{},"id":"eed74130-c87b-46c2-a97b-790ade16af8f","type":"BasicTicker"},{"attributes":{"plot":{"id":"c95e1121-9b34-4551-ac3c-0b8deb1d5440","subtype":"Chart","type":"Plot"}},"id":"af806b25-8838-4472-8318-e0802cf1cb70","type":"ResetTool"},{"attributes":{"data_source":{"id":"232345c6-33c6-4bd8-8e4b-946e2816bf5c","type":"ColumnDataSource"},"glyph":{"id":"7fa61e69-1194-48ba-8e19-80d445ca210b","type":"AnnularWedge"},"hover_glyph":null,"muted_glyph":null},"id":"4c706601-25be-4faa-8dd2-5bbc0dda4ee3","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"de17f416-8400-42ae-9592-e1db4096b5a6","type":"PanTool"},{"id":"10061940-1574-412b-839b-ab467d22511f","type":"WheelZoomTool"},{"id":"1f919fb3-263c-41d8-ba1e-74bb0a883cb7","type":"BoxZoomTool"},{"id":"1514f7c7-1a6e-47f1-9803-a12dada694ca","type":"SaveTool"},{"id":"af806b25-8838-4472-8318-e0802cf1cb70","type":"ResetTool"},{"id":"60ec89b4-0496-4a05-bf72-bc925c6e4865","type":"HelpTool"},{"id":"364adc1a-0396-4322-afb3-2b613f89a6d1","type":"HoverTool"}]},"id":"674a070e-50f5-4a55-bb27-0f82f60c2332","type":"Toolbar"},{"attributes":{"below":[{"id":"dc971aa5-6aba-4a2c-87d6-ea108a3a44ad","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"4205d218-9e8d-40b9-8d88-de1c905e3e2c","type":"LinearAxis"}],"p ...
# Current campaign Sally Hansen id 941709 got 13191594 impressions
# 20 - Processing Sally Hansen id 941709...
#       campaign_id   clientsname     countryname          devicename  \
# 9296       941709  Sally Hansen   United States              Mobile
# 9273       941709  Sally Hansen   United States  Desktop and Laptop
# 9038       941709  Sally Hansen   United States              Tablet
# 9050       941709  Sally Hansen  United Kingdom  Desktop and Laptop
# 9040       941709  Sally Hansen            None  Desktop and Laptop
# 9060       941709  Sally Hansen       Australia  Desktop and Laptop
# 9042       941709  Sally Hansen   United States             Unknown
# 9275       941709  Sally Hansen            None              Mobile
# 8822       941709  Sally Hansen          Canada  Desktop and Laptop
#
#                   startdate                enddate  totalimpressions  \
# 9296  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0           7022252
# 9273  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0           4616102
# 9038  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0            587140
# 9050  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0            108721
# 9040  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0             71935
# 9060  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0             71579
# 9042  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0             65791
# 9275  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0             60808
# 8822  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0             41573
#
#       numtotals      perct
# 9296   13191594  53.232778
# 9273   13191594  34.992754
# 9038   13191594   4.450865
# 9050   13191594   0.824169
# 9040   13191594   0.545309
# 9060   13191594   0.542611
# 9042   13191594   0.498734
# 9275   13191594   0.460960
# 8822   13191594   0.315148
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="00832b3f-ddce-4f97-ac29-a56ce7305c1b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e55efc2c-b1e3-4c51-967a-026337f9882b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e55efc2c-b1e3-4c51-967a-026337f9882b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e55efc2c-b1e3-4c51-967a-026337f9882b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e55efc2c-b1e3-4c51-967a-026337f9882b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"