# %%
import os
import sys
import pandas as pd
import pandasql as pdsql


from bkcharts import Donut
from bokeh.io import output_notebook, show

# Do this trick to add the new Beamly functionality
pythonModsRoot = '/Users/carlos.aguilar/Google Drive/PythonDev/Coding/BeamlyPython'
if pythonModsRoot not in sys.path:
    sys.path.append(pythonModsRoot)

import redshiftSqlAlchemy as rsa
import carlosUtils        as cu
import bokehUtils         as bk

from IPython.display import Markdown, display, HTML
def printmd(string):
    display(Markdown(string))

# %%
numCampaigns = 20;
cutOffPerc   = 96.0;

# set the table and schema
schemaName = 'adform'
tableName  = 'clickExtended'

# set the name of the variables to break-down
breakDownKeyWords = ['campaign_id', 'yyyy_mm_dd', 'click_detail_id_paid_keyword_id', \
'publisher_domain', 'destination_url', 'bannerid', 'bannerType', \
'client_id', 'device_type_id', 'placement_id_activity_id', 'tag_id', \
'city_id' ];

# flags to set the outputs
saveFigure    = True;
saveDFToExcel = True;

# %%
# connect to the Redshift box
user     = 'carlos_aguilar'
password = 'MdogDI64j6vH90g973'
dbname   = 'adform'
host     = 'adform-ops.c7dxcjhlundm.eu-central-1.redshift.amazonaws.com'

rs = rsa.RedshiftAlchemy(user=user, password=password, 
    database=dbname, host=host)

# %%
sqlQuery = '''SELECT count(*) as numRecords 
    from {}.{}'''.format(schemaName, tableName)
df = rs.query2DF(sqlQuery);
printmd('Analysing **' + schemaName + '.' + tableName + '** (' +  str(df.numrecords[0]) + ' records)' )
# Out:
# Analysing **adform.clickExtended** (1947522 records)

# %%
# This snippet breaks down the variables and writes the counts to a file
printmd('_Break down variables_')
for currentKey in breakDownKeyWords:
    sqlQuery = '''SELECT count(distinct({})) as numRecords 
        from {}.{}'''.format(currentKey, schemaName, tableName)
    df = rs.query2DF(sqlQuery);
    currentText = '**' + currentKey + '**' + ' has got **' + str(df.numrecords[0]) + '** unique values...'
    printmd(currentText)
# Out:
# _Break down variables_
# **campaign_id** has got **235** unique values...
# **yyyy_mm_dd** has got **66** unique values...
# **click_detail_id_paid_keyword_id** has got **1519** unique values...
# **publisher_domain** has got **8679** unique values...
# **destination_url** has got **541** unique values...
# **bannerid** has got **1421** unique values...
# **bannerType** has got **4** unique values...
# **client_id** has got **39** unique values...
# **device_type_id** has got **5** unique values...
# **placement_id_activity_id** has got **1521** unique values...
# **tag_id** has got **2549** unique values...
# **city_id** has got **82186** unique values...

# %%
# This bit takes the 'numCampaigns' most clicked campaigns and writes the results
sqlQuery = '''SELECT
A.campaign_id,
A.clientsname,
A.countryname,
A.devicename,
A.startdate,
A.enddate,
sum(A.numRecords) as totalClicks,
B.numTotals
from adform.clickExtended as A
inner join (
  SELECT  campaign_id,
  sum(numRecords) AS numTotals,
  rank() over (order by numTotals desc) as rnk
  from adform.clickExtended
  group by 1
) as B
on A.campaign_id = B.campaign_id
where B.rnk <= {}
group by 1,2,3,4,5,6,B.numTotals
order by totalclicks DESC'''.format(numCampaigns)


df        = rs.query2DF(sqlQuery)
groupedDF = df.groupby(df['campaign_id'])
idx       = 0;


# Get a list of the most clicked campaigns
vars2show = ['campaign_id', 'clientsname', 'numtotals', 'startdate', 'enddate']
df2 = df[vars2show].copy()
df2.drop_duplicates(inplace=True)
display(df2)
# Out:
#     campaign_id         clientsname  numtotals              startdate  \
# 0        919044               Gucci     282480  2017-06-04 00:00:00.0
# 1        897248           CoverGirl     171958  2017-05-15 00:00:00.0
# 2        886811        Sally Hansen     171157  2017-04-25 00:00:00.0
# 3        929026        Sally Hansen     114949  2017-06-12 00:00:00.0
# 4        918140  Wella Professional     106090  2017-06-02 00:00:00.0
# 5        950281        Sally Hansen      83873  2017-07-05 00:00:00.0
# 6        906824        Wella Retail      70696  2017-05-25 00:00:00.0
# 7        922742           Hugo Boss      83245  2017-06-05 00:00:00.0
# 8        912694    OPI Professional      67760  2017-06-01 00:00:00.0
# 10       894699              Rimmel      60649  2017-05-10 00:00:00.0
# 11       875443          Philosophy      65436  2017-04-06 00:00:00.0
# 13       909102        Sally Hansen      45505  2017-05-23 00:00:00.0
# 14       904136    Clairol Consumer      56850  2017-05-22 00:00:00.0
# 15       893988              Rimmel      73187  2017-05-11 00:00:00.0
# 16       927466            Bourjois      60215  2017-06-07 00:00:00.0
# 17       923477              Rimmel      68758  2017-06-01 00:00:00.0
# 20       891860              Escada      42503  2017-05-01 00:00:00.0
# 21       886095        Sally Hansen      46908  2017-05-01 00:00:00.0
# 22       886100        Sally Hansen      54855  2017-04-17 00:00:00.0
# 24       923123             Playboy      43711  2017-06-06 00:00:00.0
#
#                   enddate
# 0   2017-06-30 23:59:00.0
# 1   2017-06-30 23:59:00.0
# 2   2017-06-30 23:59:00.0
# 3   2017-06-30 23:59:00.0
# 4   2017-06-30 23:59:00.0
# 5   2017-07-31 23:59:00.0
# 6   2017-06-30 23:59:00.0
# 7   2017-07-23 23:59:00.0
# 8   2017-06-30 23:59:00.0
# 10  2017-06-06 23:59:00.0
# 11  2017-06-30 23:59:00.0
# 13  2017-06-26 23:59:00.0
# 14  2017-06-30 23:59:00.0
# 15  2017-06-11 23:59:00.0
# 16  2017-07-04 23:59:00.0
# 17  2017-07-30 23:59:00.0
# 20  2018-06-22 23:59:00.0
# 21  2017-06-30 23:59:00.0
# 22  2017-06-30 23:59:00.0
# 24  2017-06-30 23:59:00.0

# %%
for name, group in groupedDF:
    idx += 1;
    groupClientName = group['clientsname'].iloc[0]
    cu.printf('{} - Processing {} id {}...'.format(idx, groupClientName, name))
    print('Current campaign {} id {} got {} clicks'.format(groupClientName, \
        name, group['totalclicks'].sum()))
    
    # Get the percentage for the break down
    totalCampaignClicks = group['totalclicks'].sum();
    group['perct'] = 100.0*group['totalclicks']/totalCampaignClicks;
    
    # cutoff at 96%
    idx95p = group['perct'].cumsum() < cutOffPerc
    df95p  = group.loc[idx95p, :]

    fileName  = groupClientName + ' (id ' + str(name) + ').xlsx'
    
    display(df95p)

    # bokeh
    title  = groupClientName + \
        ' (id ' + str(name) + ') clicks: ' + str(totalCampaignClicks)
    labels = ['devicename','countryname']
    values = 'totalclicks'
    hoverText ='totalclicks'
    textFontSize = '10pt'

    donutChart = Donut(df95p, label=labels, values=values,
    text_font_size=textFontSize, hover_text=hoverText,
    title=title)
    output_notebook()
    show(donutChart)
# Out:
# Current campaign Philosophy id 875443 got 65436 clicks
# 1 - Processing Philosophy id 875443...
# /Users/carlos.aguilar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#     campaign_id clientsname    countryname devicename              startdate  \
# 11       875443  Philosophy  United States     Mobile  2017-04-06 00:00:00.0
# 35       875443  Philosophy  United States     Tablet  2017-04-06 00:00:00.0
#
#                   enddate  totalclicks  numtotals      perct
# 11  2017-06-30 23:59:00.0        52534      65436  80.283025
# 35  2017-06-30 23:59:00.0         6449      65436   9.855431
# /Users/carlos.aguilar/anaconda3/lib/python3.6/site-packages/bkcharts/builders/donut_builder.py:118: PerformanceWarning: indexing past lexsort depth may impact performance.
#   chart = create_and_build(DonutBuilder, data, **kw)
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ca20c409-49e5-4d70-98a7-07e73324a877">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="48fb5d6b-3853-4416-80b1-38aedf18a286"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("48fb5d6b-3853-4416-80b1-38aedf18a286");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("48fb5d6b-3853-4416-80b1-38aedf18a286");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '48fb5d6b-3853-4416-80b1-38aedf18a286' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b05c65f4-56fc-4789-919e-5a20fa5f5165":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"784f9faa-b7bf-41ed-be7e-c382e000e244","type":"PanTool"},{"id":"a62f3b5d-8953-4761-94ea-f74b1d2a2773","type":"WheelZoomTool"},{"id":"cb8797b0-7a72-493a-9cdf-a3a30224333f","type":"BoxZoomTool"},{"id":"08423300-c95e-435c-94b1-bf818e940aa1","type":"SaveTool"},{"id":"6a56841b-fb9c-4edb-a31b-0710712a2419","type":"ResetTool"},{"id":"078cd506-5c13-4b4b-8909-4470292b59be","type":"HelpTool"},{"id":"e9ac924e-af17-4f62-ac1e-5e4d080e6d79","type":"HoverTool"}]},"id":"7acd6b0e-3194-4168-894b-a50027db00d5","type":"Toolbar"},{"attributes":{"plot":null,"text":"Philosophy (id 875443) clicks: 65436"},"id":"8325674e-442c-466c-967a-5542a9e5b38c","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cee6503c-aac9-49a9-b1c4-6f5fecbf0ff9","type":"BoxAnnotation"},{"attributes":{"callback":null,"plot":{"id":"33e5ed9f-462f-42b0-9beb-a541975f131e","subtype":"Chart","type":"Plot"},"tooltips":[["Totalclicks","@values"]]},"id":"e9ac924e-af17-4f62-ac1e-5e4d080e6d79","type":"HoverTool"},{"attributes":{"location":"top_left","plot":{"id":"33e5ed9f-462f-42b0-9beb-a541975f131e","subtype":"Chart","type":"Plot"}},"id":"b98a6b80-cfc6-40de-b0bc-6c87b43db896","type":"Legend"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":"95f634c3-9ab9-4a82-b964-0bbd0f7b44d6","type":"AnnularWedge"},{"attributes":{"plot":{"id":"33e5ed9f-462f-42b0-9beb-a541975f131e","subtype":"Chart","type":"Plot"}},"id":"08423300-c95e-435c-94b1-bf818e940aa1","type":"SaveTool"},{"attributes":{},"id":"cd67dc47-1bf1-4e08-b85f-3d20a2842c05","type":"LinearScale"},{"attributes":{"axis_label":null,"formatter":{"id":"96232b24-91a3-4dd0-89ea-609dc12de03c","type":"BasicTickFormatter"},"plot":{"id":"33e5ed9f-462f-42b0-9beb-a541975f131e","subtype":"Chart","type":"Plot"},"ticker":{"id":"01b57e29-444c-40df-a635-69dbce7dcdfc","type":"BasicTicker"},"visible":false},"id":"18dadebe-958d-4db7-861a-b6f0ea14b78b","type":"LinearAxis"},{"attributes":{"plot":{"id":"33e5ed9f-462f-42b0-9beb-a541975f131e","subtype":"Chart","type":"Plot"}},"id":"784f9faa-b7bf-41ed-be7e-c382e000e244","type":"PanTool"},{"attributes":{},"id":"96232b24-91a3-4dd0-89ea-609dc12de03c","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":
olbar"},"x_range":{"id":"8ad88dcf-a7cc-42fc-937e-c521605c5f81","type":"Range1d"},"x_scale":{"id":"25b4f343-a6ee-485e-bf4b-e3e0835b8de6","type":"LinearScale"},"y_range":{"id":"4c855957-66e4-411b-b9d8-c2b1dd49a616","type":"Range1d"},"y_scale":{"id":"0a856ade-1b30-4ee8-908a-f3d9b6a4d0a0","type":"LinearScale"}},"id":"853845c5-4ce0-4cb3-89ef-09809ba1085c","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"0a856ade-1b30-4ee8-908a-f3d9b6a4d0a0","type":"LinearScale"},{"attributes":{"location":"top_left","plot":{"id":"853845c5-4ce0-4cb3-89ef-09809ba1085c","subtype":"Chart","type":"Plot"}},"id":"590dd16f-f0f1-464d-aa19-ce5e659379cc","type":"Legend"},{"attributes":{"callback":null,"plot":{"id":"853845c5-4ce0-4cb3-89ef-09809ba1085c","subtype":"Chart","type":"Plot"},"tooltips":[["Totalclicks","@values"]]},"id":"90862780-4060-416e-b102-ff0b6bc63910","type":"HoverTool"},{"attributes":{"axis_label":null,"formatter":{"id":"a0d8f7b5-0037-4e23-b448-f039d36398fd","type":"BasicTickFormatter"},"plot":{"id":"853845c5-4ce0-4cb3-89ef-09809ba1085c","subtype":"Chart","type":"Plot"},"ticker":{"id":"46444887-c4fd-433d-b49e-757b7a1e0704","type":"BasicTicker"},"visible":false},"id":"f868a60e-47f6-453b-85a7-4b0a20f2441d","type":"LinearAxis"},{"attributes":{"plot":null,"text":"Sally Hansen (id 886095) clicks: 46908"},"id":"40fc9beb-4ffc-44f2-9946-e7bbfc7b6669","type":"Title"},{"attributes":{"axis_label":null,"formatter":{"id":"c136518d-10ed-4444-80b6-0b91ff2561e6","type":"BasicTickFormatter"},"plot":{"id":"853845c5-4ce0-4cb3-89ef-09809ba1085c","subtype":"Chart","type":"Plot"},"ticker":{"id":"3f85bb9a-5874-4c00-8ed5-cd90300454a7","type":"BasicTicker"},"visible":false},"id":"acfe98d9-d0ae-4ff4-ae5c-b7ac52605142","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["text","x","y","text_angle"],"data":{"text":["Desktop and Laptop","Mobile","United States","United States"],"text_angle":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAALOzj5f2/fI/BRoo+njhHUA=","dtype":"float64","shape":[4]},"x":[0.4212458501795093,-0.4212458501795092,0.8424917003590185,-0.8424917003590184],"y":[1.0431571951084566,-1.0431571951084566,2.0863143902169132,-2.0863143902169132]}},"id":"9e6a9c72-9660-4c3a-b245-c8cdaf31dda9","type":"ColumnDataSource"},{"attributes":{},"id":"c136518d-10ed-4444-80b6-0b91ff2561e6","type":"BasicTickFormatter"},{"attributes":{},"id":"3f85bb9a-5874-4c00-8ed5-cd90300454a7","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha": ...
# Current campaign Sally Hansen id 886100 got 54855 clicks
# 3 - Processing Sally Hansen id 886100...
#     campaign_id   clientsname    countryname          devicename  \
# 22       886100  Sally Hansen  United States  Desktop and Laptop
# 25       886100  Sally Hansen  United States              Mobile
# 47       886100  Sally Hansen  United States              Tablet
# 68       886100  Sally Hansen  United States             Unknown
#
#                 startdate                enddate  totalclicks  numtotals  \
# 22  2017-04-17 00:00:00.0  2017-06-30 23:59:00.0        26125      54855
# 25  2017-04-17 00:00:00.0  2017-06-30 23:59:00.0        22383      54855
# 47  2017-04-17 00:00:00.0  2017-06-30 23:59:00.0         3133      54855
# 68  2017-04-17 00:00:00.0  2017-06-30 23:59:00.0          796      54855
#
#         perct
# 22  47.625558
# 25  40.803938
# 47   5.711421
# 68   1.451098
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3017d592-316a-49df-9aa5-7d7193f087ef">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a462c77c-0e36-42bf-ac52-afb3d94fa746"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a462c77c-0e36-42bf-ac52-afb3d94fa746");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a462c77c-0e36-42bf-ac52-afb3d94fa746");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a462c77c-0e36-42bf-ac52-afb3d94fa746' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"
},{"attributes":{"callback":null,"end":3.1500000000000004,"start":-3.1500000000000004},"id":"7b787b21-20d8-4f8b-9d5a-d1457233c67e","type":"Range1d"},{"attributes":{},"id":"3ef24768-f6b2-476e-839c-4e895eb8f4d0","type":"ToolEvents"},{"attributes":{"plot":{"id":"993f694f-787a-48df-aece-cda3a57d6e05","subtype":"Chart","type":"Plot"}},"id":"7824bb08-6e50-43bb-ba8b-8df653e8f207","type":"ResetTool"},{"attributes":{"angle":{"field":"text_angle","units":"rad"},"text_align":"center","text_baseline":"middle","text_font_size":{"value":"10pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6e376761-509f-4601-bcd7-cfb089f28d71","type":"Text"},{"attributes":{"below ...
# Current campaign Sally Hansen id 950281 got 83873 clicks
# 20 - Processing Sally Hansen id 950281...
#     campaign_id   clientsname    countryname devicename  \
# 5        950281  Sally Hansen  United States     Mobile
# 36       950281  Sally Hansen  United States     Tablet
#
#                 startdate                enddate  totalclicks  numtotals  \
# 5   2017-07-05 00:00:00.0  2017-07-31 23:59:00.0        72795      83873
# 36  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0         6203      83873
#
#         perct
# 5   86.791935
# 36   7.395705
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4ea1f634-8550-4622-a679-899854205406">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="366b6bf1-02b7-4750-81c1-01cb710077f2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("366b6bf1-02b7-4750-81c1-01cb710077f2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("366b6bf1-02b7-4750-81c1-01cb710077f2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '366b6bf1-02b7-4750-81c1-01cb710077f2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bfe77bfe-1827-4093-a512-43e3c3920acc":{"roots":{"references":[{"attributes":{"plot":{"id":"3bb9900c-47fc-4b19-9eca-085fbef40e76","subtype":"Chart","type":"Plot"}},"id":"d9653868-9870-4520-a3e7-8a2eaf8d9813","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c6c82fe7-42d6-4566-84db-b9e041b5940c","type":"PanTool"},{"id":"d9653868-9870-4520-a3e7-8a2eaf8d9813","type":"WheelZoomTool"},{"id":"aba71237-b260-4eae-bda8-f7df6ecfe20a","type":"BoxZoomTool"},{"id":"b0a606ce-c988-4ad1-ad2b-e75ebdd3b0fc","type":"SaveTool"},{"id":"9d2f7ad1-3c21-41e3-9fe4-4fce1dcf051a","type":"ResetTool"},{"id":"71d57ef2-0bd0-4dd5-8090-46d0b1984029","type":"HelpTool"},{"id":"3aa08c01-4c06-4c7c-b0d8-410d441fd34f","type":"HoverTool"}]},"id":"17ef87de-ece5-47ee-9b01-a3554db12d74","type":"Toolbar"},{"attributes":{},"id":"e9214432-1398-4cee-9841-b9863ce4cfbd","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"989485d2-000f-4181-9c49-3e7fe3ef6017","type":"BoxAnnotation"},"plot":{"id":"3bb9900c-47fc-4b19-9eca-085fbef40e76","subtype":"Chart","type":"Plot"}},"id":"aba71237-b260-4eae-bda8-f7df6ecfe20a","type":"BoxZoomTool"},{"attributes":{},"id":"875c06f4-5111-4109-b71b-8527c5b11a97","type":"BasicTicker"},{"attributes":{},"id":"8befe3bd-2da9-40bd-a6f0-49b1469e5d8a","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3bb9900c-47fc-4b19-9eca-085fbef40e76","subtype":"Chart","type":"Plot"}},"id":"71d57ef2-0bd0-4dd5-8090-46d0b1984029","type":"HelpTool"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":"568a319f-8e9d-43b8-a98b-9c03672a3c7e","type":"AnnularWedge"},{"attributes":{},"id":"cd904e20-6684-41fc-a93c-5d6faedd28a2","type":"LinearScale"},{"attributes":{"callback":null,"end":3.1500000000000004,"start":-3.1500000000000004},"id":"f4081cb5-6179-4976-b97b-ba113f24d428","type":"Range1d"},{"attributes":{"callback":null,"end":3.1500000000000004,"start":-3.1500000000000004},"id":"c9802e1e-be5d-4ba9-8b54-8981e029b3f9","type":"Range1d"},{"attributes":{"axis_label":null,"formatter":{"id":"8befe3bd-2da9-40bd-a6f0-49b1469e5d8a","type":"BasicTickFormatter"},"plot":{"id":"3bb9900c-47fc-4b19-9eca-085fbef40e76","subtype":"Chart","type":"Plot"},"ticker":{"id":"875c06f4-5111-4109-b71b-8527c5b11a97","type":"BasicTicker"},"visible":false},"id":"4acdcfdd-0faa-42a8-9846-342ad557ae06","type":"LinearAxis"},{"attributes":{"data_source":{"id":"03415b59-0488-4131-a972-8a31d3c8827a","type":"ColumnDataSource"},"glyph":{"id":"568a319f-8e9d-43b8-a98b-9c03672a3c7e","type":"AnnularWedge"},"hover_glyph":null,"muted_glyph":null},"id":"f3e6518d-4f73-44ba-9a4b-52083880941c","type":"GlyphRenderer"},{"attributes":{"angle":{"field":"text_angle","units":"rad"},"text_align":"center","text_baseline":"middle","text_font_size":{"value":"10pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d2a56fba-fcfe-43f6-b6d1-bfbdb7e21805","type":"Text"},{"attributes":{"plot":null,"text":"Sally Hansen (id 950281) clicks: 83873"},"id":"afa375ce-6709-4380-89de-06b995a35a35","type":"Title"},{"attributes":{"axis_label":null,"formatter":{"id":"e9214432-1398-4cee-9841-b9863ce4cfbd","type":"BasicTickFormatter"},"plot":{"id":"3bb9900c-47fc-4b19-9eca-085fbef40e76","subtype":"Chart","type":"Plot"},"ticker":{"id":"2372c729-1add-482a-bd19-d9e497e71bc0","type":"BasicTicker"},"visible":false},"id":"17ae09ec-d4ff-44d5-865d-94ab3daa942a","type":"LinearAxis"},{"attributes":{"location":"top_left","plot":{"id":"3bb9900c-47fc-4b19-9eca-085fbef40e76","subtype":"Chart","type":"Plot"}},"id":"d3b1c60e-3c52-4c7f-acf3-df87cd840ca1","type":"Legend"},{"attributes":{"callback":null,"column_names":["end","level","start","values","inners","outers","cent ...

# %%
# Assuming that dataframes df1 and df2 are already defined:

display(df)
print('Dataframe 2:')
HTML(df.to_html())
# Out:
#       campaign_id         clientsname                       countryname  \
# 0          919044               Gucci                             Italy
# 1          897248           CoverGirl                     United States
# 2          886811        Sally Hansen                     United States
# 3          929026        Sally Hansen                     United States
# 4          918140  Wella Professional                    United Kingdom
# 5          950281        Sally Hansen                     United States
# 6          906824        Wella Retail                    United Kingdom
# 7          922742           Hugo Boss                            Poland
# 8          912694    OPI Professional                     United States
# 9          886811        Sally Hansen                     United States
# 10         894699              Rimmel                    United Kingdom
# 11         875443          Philosophy                     United States
# 12         919044               Gucci                             Italy
# 13         909102        Sally Hansen                             Italy
# 14         904136    Clairol Consumer                     United States
# 15         893988              Rimmel                             Spain
# 16         927466            Bourjois                            Poland
# 17         923477              Rimmel                            France
# 18         919044               Gucci                             Italy
# 19         893988              Rimmel                             Spain
# 20         891860              Escada                             Spain
# 21         886095        Sally Hansen                     United States
# 22         886100        Sally Hansen                     United States
# 23         923477              Rimmel                            France
# 24         923123             Playboy                            Poland
# 25         886100        Sally Hansen                     United States
# 26         923123             Playboy                            Poland
# 27         927466            Bourjois                            Poland
# 28         897248           CoverGirl                     United States
# 29         886095        Sally Hansen                     United States
# ...           ...                 ...                               ...
# 2360       918140  Wella Professional                      Sierra Leone
# 2361       950281        Sally Hansen                             Chile
# 2362       886095        Sally Hansen                           Nigeria
# 2363       886095        Sally Hansen                         Argentina
# 2364       886095        Sally Hansen                            Poland
# 2365       918140  Wella Professional                            Israel
# 2366       918140  Wella Professional                          Cambodia
# 2367       929026        Sally Hansen                             Malta
# 2368       875443          Philosophy                Russian Federation
# 2369       929026        Sally Hansen                         Indonesia
# 2370       886100        Sally Hansen                           Senegal
