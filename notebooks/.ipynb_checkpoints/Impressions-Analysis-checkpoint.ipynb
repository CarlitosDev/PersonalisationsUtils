# %%
import os
import sys
import pandas as pd
import pandasql as pdsql


from bkcharts import Donut
from bokeh.io import output_notebook, show

# Do this trick to add the new Beamly functionality
pythonModsRoot = '/Users/carlos.aguilar/Google Drive/PythonDev/Coding/BeamlyPython'
if pythonModsRoot not in sys.path:
    sys.path.append(pythonModsRoot)

import redshiftSqlAlchemy as rsa
import carlosUtils        as cu
import bokehUtils         as bk

from IPython.display import Markdown, display, HTML
def printmd(string):
    display(Markdown(string))

# %%
numCampaigns = 20;
cutOffPerc   = 96.0;

# %%
# set the table and schema
schemaName = 'adform'
tableName  = 'impressionsExtended'

# set the name of the variables to break-down
breakDownKeyWords = ['campaign_id', 'yyyy_mm_dd', \
'publisher_domain', 'bannerid', 'bannerType', \
'client_id', 'device_type_id', 'placement_id_activity_id', 'tag_id', \
'city_id' ];

# flags to set the outputs
saveFigure    = True;
saveDFToExcel = True;

# %%
# connect to the Redshift box
user     = 'carlos_aguilar'
password = 'MdogDI64j6vH90g973'
dbname   = 'adform'
host     = 'adform-ops.c7dxcjhlundm.eu-central-1.redshift.amazonaws.com'

rs = rsa.RedshiftAlchemy(user=user, password=password, 
    database=dbname, host=host)

# %%
sqlQuery = '''SELECT count(*) as numRecords 
    from {}.{}'''.format(schemaName, tableName)
df = rs.query2DF(sqlQuery);
printmd('Analysing **' + schemaName + '.' + tableName + '** (' +  str(df.numrecords[0]) + ' records)' )
# Out:
# Analysing **adform.impressionsExtended** (195387010 records)

# %%
# This snippet breaks down the variables and writes the counts to a file
printmd('_Break down variables_ from ' +  schemaName +'.' + tableName)
for currentKey in breakDownKeyWords:
    sqlQuery = '''SELECT count(distinct({})) as numRecords 
        from {}.{}'''.format(currentKey, schemaName, tableName)
    df = rs.query2DF(sqlQuery);
    currentText = '**' + currentKey + '**' + ' has got **' + str(df.numrecords[0]) + '** unique values...'
    printmd(currentText)
# Out:
# _Break down variables_ from adform.impressionsExtended
# **campaign_id** has got **247** unique values...
# **yyyy_mm_dd** has got **66** unique values...
# **publisher_domain** has got **276148** unique values...
# **bannerid** has got **1454** unique values...
# **bannerType** has got **4** unique values...
# **client_id** has got **37** unique values...
# **device_type_id** has got **5** unique values...
# **placement_id_activity_id** has got **1636** unique values...
# **tag_id** has got **3091** unique values...
# **city_id** has got **220894** unique values...

# %%
# This bit takes the 'numCampaigns' most clicked campaigns and writes the results

sqlQuery = '''SELECT
A.campaign_id,
A.clientsname,
A.countryname,
A.devicename,
A.startdate,
A.enddate,
sum(A.numRecords) as totalImpressions,
B.numTotals
from adform.impressionsExtended as A
inner join (
  SELECT  campaign_id,
  sum(numRecords) AS numTotals,
  rank() over (order by numTotals desc) as rnk
  from adform.impressionsExtended
  group by 1
) as B
on A.campaign_id = B.campaign_id
where B.rnk <= {}
group by 1,2,3,4,5,6,B.numTotals
order by numTotals DESC'''.format(numCampaigns)


df        = rs.query2DF(sqlQuery)
groupedDF = df.groupby(df['campaign_id'])
idx       = 0;


# Get a list of the most clicked campaigns
vars2show = ['campaign_id', 'clientsname', 'numtotals', 'startdate', 'enddate']
df2 = df[vars2show].copy()
df2.drop_duplicates(inplace=True)
display(df2)
# Out:
#       campaign_id       clientsname  numtotals              startdate  \
# 0          897248         CoverGirl  104971036  2017-05-15 00:00:00.0
# 358        886811      Sally Hansen   48491511  2017-04-25 00:00:00.0
# 746        929928  Clairol Consumer   41799226  2017-06-15 00:00:00.0
# 1480       886100      Sally Hansen   41189281  2017-04-17 00:00:00.0
# 2177       886095      Sally Hansen   32643950  2017-05-01 00:00:00.0
# 2856       888329      Sally Hansen   32176714  2017-05-08 00:00:00.0
# 3269       894699            Rimmel   30504815  2017-05-10 00:00:00.0
# 3833       912694  OPI Professional   28922186  2017-06-01 00:00:00.0
# 4545       886846      Sally Hansen   20148263  2017-05-08 00:00:00.0
# 5266       903883            Rimmel   19277041  2017-05-18 00:00:00.0
# 5831       923338            Rimmel   17903269  2017-06-07 00:00:00.0
# 6502       907580      Calvin Klein   17698973  2017-05-19 00:00:00.0
# 6955       930891  OPI Professional   15421693  2017-06-16 00:00:00.0
# 7641       904136  Clairol Consumer   15178309  2017-05-22 00:00:00.0
# 7769       875443        Philosophy   14802201  2017-04-06 00:00:00.0
# 8062       930443       Marc Jacobs   13943022  2017-06-14 00:00:00.0
# 8472       930412            Adidas   13745391  2017-06-08 00:00:00.0
# 8572       923742         CoverGirl   13220398  2017-06-01 00:00:00.0
# 8822       941709      Sally Hansen   13191594  2017-07-05 00:00:00.0
# 9499       916730      Calvin Klein   12781501  2017-05-30 00:00:00.0
#
#                     enddate
# 0     2017-06-30 23:59:00.0
# 358   2017-06-30 23:59:00.0
# 746   2017-06-30 23:59:00.0
# 1480  2017-06-30 23:59:00.0
# 2177  2017-06-30 23:59:00.0
# 2856  2017-06-30 23:59:00.0
# 3269  2017-06-06 23:59:00.0
# 3833  2017-06-30 23:59:00.0
# 4545  2017-06-30 23:59:00.0
# 5266  2017-06-10 23:59:00.0
# 5831  2017-06-30 23:59:00.0
# 6502  2017-06-25 23:59:00.0
# 6955  2017-06-30 23:59:00.0
# 7641  2017-06-30 23:59:00.0
# 7769  2017-06-30 23:59:00.0
# 8062  2017-06-28 23:59:00.0
# 8472  2017-06-30 23:59:00.0
# 8572  2017-06-25 23:59:00.0
# 8822  2017-07-31 23:59:00.0
# 9499  2017-06-25 23:59:00.0

# %%
for name, group in groupedDF:
    idx += 1;
    groupClientName = group['clientsname'].iloc[0]
    cu.printf('{} - Processing {} id {}...'.format(idx, groupClientName, name))
    print('Current campaign {} id {} got {} impressions'.format(groupClientName, \
        name, group['totalimpressions'].sum()))
    
    # Get the percentage for the break down
    totalCampaignClicks = group['totalimpressions'].sum();
    group['perct'] = 100.0*group['totalimpressions']/totalCampaignClicks;
    group.sort_values(['perct'], ascending=[0], inplace = True)
    
    # cutoff at 96%
    idx95p = group['perct'].cumsum() < cutOffPerc
    df95p  = group.loc[idx95p, :]

    fileName  = groupClientName + ' (id ' + str(name) + ').xlsx'
    

    display(df95p)

    # bokeh
    title  = groupClientName + \
        ' (id ' + str(name) + ') clicks: ' + str(totalCampaignClicks)
    labels = ['devicename','countryname']
    values = 'totalimpressions'
    hoverText ='totalimpressions'
    textFontSize = '10pt'

    donutChart = Donut(df95p, label=labels, values=values,
    text_font_size=textFontSize, hover_text=hoverText,
    title=title)
    output_notebook()
    show(donutChart)
# Out:
# Current campaign Philosophy id 875443 got 14802201 impressions
# 1 - Processing Philosophy id 875443...
# /Users/carlos.aguilar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/carlos.aguilar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#       campaign_id clientsname    countryname          devicename  \
# 7859       875443  Philosophy  United States              Mobile
# 7968       875443  Philosophy  United States  Desktop and Laptop
#
#                   startdate                enddate  totalimpressions  \
# 7859  2017-04-06 00:00:00.0  2017-06-30 23:59:00.0           7137526
# 7968  2017-04-06 00:00:00.0  2017-06-30 23:59:00.0           4150401
#
#       numtotals      perct
# 7859   14802201  48.219356
# 7968   14802201  28.039080
# /Users/carlos.aguilar/anaconda3/lib/python3.6/site-packages/bkcharts/builders/donut_builder.py:118: PerformanceWarning: indexing past lexsort depth may impact performance.
#   chart = create_and_build(DonutBuilder, data, **kw)
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5cfdb949-2058-4fa4-be15-b9940052d404">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="74724ba4-8a64-490a-a870-52fc585f3f8d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("74724ba4-8a64-490a-a870-52fc585f3f8d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("74724ba4-8a64-490a-a870-52fc585f3f8d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '74724ba4-8a64-490a-a870-52fc585f3f8d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f2cb0452-aa6a-42a8-bac5-0360988af145":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["end","level","start","values","inners","outers","centers","color","devicename_countryname"],"data":{"centers":{"__ndarray__":"AAAAAAAA8j8AAAAAAADyPwAAAAAAAAJAAAAAAAAAAkA=","dtype":"float64","shape":[4]},"color":["#f22c40","#5ab738","#f22c40","#5ab738"],"devicename_countryname":[["Desktop and Laptop",""],["Mobile",""],["Desktop and Laptop","United States"],["Mobile","United States"]],"end":{"__ndarray__":"rSQ6Tlt7AkAYLURU+yEZQK0kOk5bewJAGC1EVPshGUA=","dtype":"float64","shape":[4]},"inners":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAPg/AAAAAAAA+D8=","dtype":"float64","shape":[4]},"level":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAPA/AAAAAAAA8D8=","dtype":"float64","shape":[4]},"outers":{"__ndarray__":"AAAAAAAA+D8AAAAAAAD4PwAAAAAAAAhAAAAAAAAACEA=","dtype":"float64","shape":[4]},"start":{"__ndarray__":"AAAAAAAAAACtJDpOW3sCQAAAAAAAAAAArSQ6Tlt7AkA=","dtype":"float64","shape":[4]},"values":[4150401,7137526,4150401,7137526]}},"id":"0fd317e7-d937-40ab-9992-fdb08b8ecc4f","type":"ColumnDataSource"},{"attributes":{},"id":"9cc9d3c4-d58a-422b-a32c-1cba8390226a","type":"BasicTicker"},{"attributes":{},"id":"cc6df015-71a7-4b31-91f9-0768a3ea9485","type":"BasicTickFormatter"},{"attributes":{"angle":{"field":"text_angle","units":"rad"},"text_align":"center","text_baseline":"middle","text_font_size":{"value":"10pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bffeb3b3-f9bb-40e4-851f-484c97f5d607","type":"Text"},{"attributes":{},"id":"c784eb9b-d028-45cf-b96d-3818e9c9a59a","type":"BasicTicker"},{"attributes":{"plot":{"id":"b81870ab-3ad0-47a9-9d27-32eb8d824435","subtype":"Chart","type":"Plot"}},"id":"ca33b990-984d-48ad-ae27-25f22d181221","type":"ResetTool"},{"attributes":{"axis_label":null,"formatter":{"id":"cc6df015-71a7-4b31-91f9-0768a3ea9485","type":"BasicTickFormatter"},"plot":{"id":"b81870ab-3ad0-47a9-9d27-32eb8d824435","subtype":"Chart","type":"Plot"},"ticker":{"id":"c784eb9b-d028-45cf-b96d-3818e9c9a59a","type":"BasicTicker"},"visible":false},"id":"d07fc404-65f2-4180-baec-850a58bac2e7","type":"LinearAxis"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":
id":"35faa663-c75d-4517-8b5c-3fa4a135229e","subtype":"Chart","type":"Plot"}},"id":"d55bd136-a487-4e45-93fb-60c321b7ebba","type":"SaveTool"},{"attributes":{"plot":{"id":"35faa663-c75d-4517-8b5c-3fa4a135229e","subtype":"Chart","type":"Plot"}}," ...
# Current campaign Sally Hansen id 886100 got 41189281 impressions
# 3 - Processing Sally Hansen id 886100...
#       campaign_id   clientsname    countryname devicename  \
# 1480       886100  Sally Hansen  United States     Mobile
#
#                   startdate                enddate  totalimpressions  \
# 1480  2017-04-17 00:00:00.0  2017-06-30 23:59:00.0          21400058
#
#       numtotals      perct
# 1480   41189281  51.955406
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3d0bd353-68ca-493a-8e4d-c2dd9129db14">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="70971021-cf2c-47a4-9d26-970f9fb9cd36"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("70971021-cf2c-47a4-9d26-970f9fb9cd36");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("70971021-cf2c-47a4-9d26-970f9fb9cd36");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '70971021-cf2c-47a4-9d26-970f9fb9cd36' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4dda399b-30b6-4bd6-bfb6-0e2ff3b74d3a":{"roots":{"references":[{"attributes":{"data_source":{"id":"eb67593c-eacc-43ab-bbfe-87e362de436d","type":"ColumnDataSource"},"glyph":{"id":"db3b82c4-2913-4e4c-91ce-d7deccc59b61","type":"AnnularWedge"},"hover_glyph":null,"muted_glyph":null},"id":"1faa2abd-0e30-40e7-a0b0-2ed54fbaacda","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"bbb6fa5f-b6c1-4883-8f51-c581ead1152f","subtype":"Chart","type":"Plot"}},"id":"b5273201-cb03-4ee4-8189-c049f24796f1","type":"PanTool"},{"attributes":{"location":"top_left","plot":{"id":"bbb6fa5f-b6c1-4883-8f51-c581ead1152f","subtype":"Chart","type":"Plot"}},"id":"be6e7594-f97a-4db6-a82b-811a2974f04d","type":"Legend"},{"attributes":{"plot":{"id":"bbb6fa5f-b6c1-4883-8f51-c581ead1152f","subtype":"Chart","type":"Plot"}},"id":"1b786e7c-b4dd-4f42-af8f-93d502d0eb5f","type":"WheelZoomTool"},{"attributes":{},"id":"a9a4ab9a-0492-4166-a8ab-6847fd3143b7","type":"BasicTickFormatter"},{"attributes":{},"id":"c11dbbe5-4b1f-483a-bc8c-fc0d5d7189b2","type":"BasicTicker"},{"attributes":{"plot":{"id":"bbb6fa5f-b6c1-4883-8f51-c581ead1152f","subtype":"Chart","type":"Plot"}},"id":"9cbe66ae-4a8a-4ea7-8e1b-82c593922656","type":"SaveTool"},{"attributes":{"axis_label":null,"formatter":{"id":"befbc2de-20b2-4438-9581-0f22bc79001c","type":"BasicTickFormatter"},"plot":{"id":"bbb6fa5f-b6c1-4883-8f51-c581ead1152f","subtype":"Chart","type":"Plot"},"ticker":{"id":"498cc695-8972-47ba-a0ad-b0f2be984e9f","type":"BasicTicker"},"visible":false},"id":"6b0fe410-233a-42e4-92fa-087113c5bacc","type":"LinearAxis"},{"attributes":{"callback":null,"end":3.1500000000000004,"start":-3.1500000000000004},"id":"6c5ba0d4-4a92-45ac-ad58-5f412b0252b6","type":"Range1d"},{"attributes":{},"id":"3e6b52b2-2347-44a9-97b6-7f9c890b7e1d","type":"ToolEvents"},{"attributes":{},"id":"befbc2de-20b2-4438-9581-0f22bc79001c","type":"BasicTickFormatter"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":
type":"Range1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d7e6b4c9-1471-45df-8f4e-6f2d7fab0036","type":"BoxAnnotation"},{"attributes":{},"id":"24c7ff0f-a314-4492-bd97-6c3d6217b7cf","type":"ToolEvents"},{"attributes":{},"id":"15416e43-498c-4a20-8cf8-517ac84272d5","type":"BasicTicker"},{"attributes":{"plot":{"id":"d9e0d353-0127-4b1f-97a9-c0e124c3c3dc","subtype":"Chart","type":"Plot"}},"id":"b2ab9bec-64fb-41c5-ab81-37acbb069436","type":"PanTool"},{"attributes":{"callback":null,"column_names":["text","x","y","text_angle"],"data":{"text":["Mobile","United States"],"text_angle":{"__ndarray__":"AAAAAAAAAAAYLURU+yEZQA==","dtype":"float64","shape":[2]},"x":[-1.125,-2.25],"y":[1.3777276490407724e-16,2.755455298081545e-16]}},"id":"a40360dd-4170-4066-adbc-1c64f4090cc3","type":"ColumnDataSource"},{"attributes":{"location":"top_left","plot":{"id":"d9e0d353-0127-4b1f-97a9-c0e124c3c3dc","subtype":"Chart","type":"Plot"}},"id":"4172067c-d675-4b7f-8d78-4c6731aafa1a","type":"Legend"},{"attributes":{"callback":null,"plot":{"id":"d9e0d353-0127-4b1f-97a9-c0e124c3c3dc","subtype":"Chart","type":"Plot"},"tooltips":[["Totalimpressions","@values"]]},"id":"b51fb5e3-c1af-4148-a3d2-ede40f5772d5","type":"HoverTool"},{"attributes":{"angle":{"field":"text_angle","units":"rad"},"text_align":"center","text_baseline":"middle","text_font_size":{"value":"10pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"51993e97-28a0-4e4e-bc35-a39cc535e844","type":"Text"},{"attributes":{"data_source":{"id":"a40360dd-4170-4066-adbc-1c64f4090cc3","type":"ColumnDataSource"},"glyph":{"id":"51993e97-28a0-4e4e-bc35-a39cc535e844","type":"Text"},"hover_glyph":null,"muted_glyph":null},"id":"e074748d-3b09-4f2c-a220-aedbce578bcf","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"d7e6b4c9-1471-45df-8f4e-6f2d7fab0036","type":"BoxAnnotation"},"plot":{"id":"d9e0d353-0127-4b1f-97a9-c0e124c3c3dc","subtype":"Chart","type":"Plot"}},"id":"aa524460-fcb7-4910-8582-c20bf257246e","type":"BoxZoomTool"},{"attributes":{},"id":"be2afdae-afc9-4483-aab1-075a308f8080","type":"BasicTickFormatter"},{"attributes":{},"id":"726f0c60-f070-43e6-8cb1-bc107bb0afae","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"d9e0d353-0127-4b1f-97a9-c0e124c3c3dc","subtype":"Chart","type":"Plot"}},"id":"25444509-5c6b-47e5-8f57-3ed802be0265","type":"HelpTool"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":"31014ab3-bce1-4fc8-bc76-5e25010c26dc","type":"AnnularWedge"},{"attributes":{"axis_label":null,"formatter":{"id":"726f0c60-f070-43e6-8cb1-bc107bb0afae","type":"BasicTickFormatter"},"plot":{"id":"d9e0d353-0127-4b1f-97a9-c0e124c3c3dc","subtype":"Chart","type":"Plot"},"ticker":{"id":"15416e43-498c-4a20-8cf8-517ac84272d5","type":"BasicTicker"},"visible":false},"id":"820ad06b-8945-465d-9d6c-79a8e55f237e","type":"LinearAxis"},{"attributes":{},"id":"116043e7-a243-4d00-adea-3d4b0ef0bba2","type":"LinearScale"},{"attributes":{"callback":null,"column_names":["end","level","start","values","inners","outers","centers","color","devicename_coun ...
# Current campaign Sally Hansen id 886846 got 20148263 impressions
# 5 - Processing Sally Hansen id 886846...
#       campaign_id   clientsname    countryname          devicename  \
# 4546       886846  Sally Hansen  United States  Desktop and Laptop
# 5034       886846  Sally Hansen  United States              Mobile
# 4548       886846  Sally Hansen  United States              Tablet
#
#                   startdate                enddate  totalimpressions  \
# 4546  2017-05-08 00:00:00.0  2017-06-30 23:59:00.0           7828394
# 5034  2017-05-08 00:00:00.0  2017-06-30 23:59:00.0           4461811
# 4548  2017-05-08 00:00:00.0  2017-06-30 23:59:00.0           4121387
#
#       numtotals      perct
# 4546   20148263  38.853940
# 5034   20148263  22.144892
# 4548   20148263  20.455297
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="
b932-5231c81cd014","type":"ToolEvents"},{"attributes":{"overlay":{"id":"d68a52bc-b1f6-487d-bcb8-3520f78d29d5","type":"BoxAnnotation"},"plot":{"id":"c0c0657a-1222-48a1-8643-ed9b46760f32","subtype":"Chart","type":"Plot"}},"id":"89e74b33-fc3a-4871-bf8a-0d01e4feb805","type":"BoxZoomTool"},{"attributes":{},"id":"b005553f-d8a6-41fe-970a-f835d5cf4fba","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"e6b5cd76-1d2f-4d70-988a-f61b73137160","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"173bdc59-68fe-4dfc-b256-fef3e4c23939","type":"LinearAxis"}],"plot_height":400,"plot_width ...
# Current campaign Sally Hansen id 888329 got 32176714 impressions
# 6 - Processing Sally Hansen id 888329...
#       campaign_id   clientsname    countryname          devicename  \
# 2999       888329  Sally Hansen  United States  Desktop and Laptop
# 2856       888329  Sally Hansen  United States              Mobile
# 3001       888329  Sally Hansen  United States              Tablet
#
#                   startdate                enddate  totalimpressions  \
# 2999  2017-05-08 00:00:00.0  2017-06-30 23:59:00.0          11152329
# 2856  2017-05-08 00:00:00.0  2017-06-30 23:59:00.0           8609426
# 3001  2017-05-08 00:00:00.0  2017-06-30 23:59:00.0           6913464
#
#       numtotals      perct
# 2999   32176714  34.659627
# 2856   32176714  26.756697
# 3001   32176714  21.485923
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7feb0ef7-e237-47e1-8947-3e0ba41c252c">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2826fd48-5826-4efc-bacd-1c273a97b73a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2826fd48-5826-4efc-bacd-1c273a97b73a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2826fd48-5826-4efc-bacd-1c273a97b73a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2826fd48-5826-4efc-bacd-1c273a97b73a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
# ...
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9d505474-9121-4764-91d7-c1f08cc7f758"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9d505474-9121-4764-91d7-c1f08cc7f758");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9d505474-9121-4764-91d7-c1f08cc7f758");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9d505474-9121-4764-91d7-c1f08cc7f758' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6b179799-4ebe-4bc7-bcfb-c418d3cb8f1d":{"roots":{"references":[{"attributes":{},"id":"63773311-76dc-4206-8958-3ce27c9cdedd","type":"BasicTicker"},{"attributes":{"plot":{"id":"a61c9575-b9af-42c2-a725-a8d2cface7a9","subtype":"Chart","type":"Plot"}},"id":"8db666dc-74fd-4144-9a76-a9223a6cc378","type":"HelpTool"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":"60229304-a80f-4c32-a3f1-c59ae8d41130","type":"AnnularWedge"},{"attributes":{"plot":{"id":"a61c9575-b9af-42c2-a725-a8d2cface7a9","subtype":"Chart","type":"Plot"}},"id":"eee448be-755d-40d1-a4c4-d4fb2dcec207","type":"PanTool"},{"attributes":{},"id":"d2f58d1b-57f4-4f86-8ffb-f2fe4088996e","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ed5796f3-c1f9-43c1-a0ba-df6225e4fdd0","type":"BoxAnnotation"},{"attributes":{"callback":null,"end":3.1500000000000004,"start":-3.1500000000000004},"id":"0f37c888-a0c7-43de-928d-c1d532ac8ebc","type":"Range1d"},{"attributes":{"callback":null,"end":3.1500000000000004,"start":-3.1500000000000004},"id":"aeae5a1d-94f7-4746-9464-c185dfe813bc","type":"Range1d"},{"attributes":{},"id":"9e228730-723c-4b35-bc40-0c59d9f6c5ac","type":"LinearScale"},{"attributes":{"plot":null,"text":"OPI Professional (id 930891) clicks: 15421693"},"id":"67a13710-a622-4731-aa9c-267064ba43c9","type":"Title"},{"attributes":{},"id":"0aa29d80-51b4-4c9c-aee2-45d898b08a5d","type":"LinearScale"},{"attributes":{"axis_label":null,"formatter":{"id":"d2f58d1b-57f4-4f86-8ffb-f2fe4088996e","type":"BasicTickFormatter"},"plot":{"id":"a61c9575-b9af-42c2-a725-a8d2cface7a9","subtype":"Chart","type":"Plot"},"ticker":{"id":"63773311-76dc-4206-8958-3ce27c9cdedd","type":"BasicTicker"},"visible":false},"id":"5eedeab4-3730-4331-9279-30250df46add","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["end","level","start","values","inners","outers","centers","color","devicename_countryname"],"data":{"centers":{"__ndarray__":"AAAAAAAA8j8AAAAAAADyPwAAAAAAAAJAAAAAAAAAAkA=","dtype":"float64","shape":[4]},"color":["#f22c40","#5ab738","#f22c40","#5ab738"],"devicename_countryname":[["Mobile",""],["Tablet",""],["Mobile","United Kingdom"],["Tablet","United Kingdom"]],"end":{"__ndarray__":"gAmTNO/zFkAYLURU+yEZQIAJkzTv8xZAGC1EVPshGUA=","dtype":"float64","shape":[4]},"inners":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAPg/AAAAAAAA+D8=","dtype":"float64","shape":[4]},"level":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAPA/AAAAAAAA8D8=","dtype":"float64","shape":[4]},"outers":{"__ndarray__":"AAAAAAAA+D8AAAAAAAD4PwAAAAAAAAhAAAAAAAAACEA=","dtype":"float64","shape":[4]},"start":{"__ndarray__":"AAAAAAAAAACACZM07/MWQAAAAAAAAAAAgAmTNO/zFkA=","dtype":"float64","shape":[4]},"values":[12702134,1206343,12702134,1206343]}},"id":"5de122bd-3bc0-4a2f-8550-36cd8b2d0d87","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"5de122bd-3bc0-4a2f-8550-36cd8b2d0d87","type":"ColumnDataSource"},"glyph":{"id":"60229304-a80f-4c32-a3f1-c59ae8d41130","type":"AnnularWedge"},"hover_glyph":null,"muted_glyph":null},"id":"25ae10f9-1bf4-4ec4-86e1-399be66373f8","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"a61c9575-b9af-42c2-a725-a8d2cface7a9","subtype":"Chart","type":"Plot"}},"id":"156c00ef-ccba-4184-9502-c337620cae47","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"a61c9575-b9af-42c2-a725-a8d2cface7a9","subtype":"Chart","type":"Plot"}},"id":"c117a4e5-a6d3-4e5f-8bf4-11dfc4f76c9d","type":"ResetTool"},{"attributes" ...
# Current campaign Sally Hansen id 941709 got 13191594 impressions
# 20 - Processing Sally Hansen id 941709...
#       campaign_id   clientsname    countryname          devicename  \
# 9296       941709  Sally Hansen  United States              Mobile
# 9273       941709  Sally Hansen  United States  Desktop and Laptop
# 9038       941709  Sally Hansen  United States              Tablet
#
#                   startdate                enddate  totalimpressions  \
# 9296  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0           7022252
# 9273  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0           4616102
# 9038  2017-07-05 00:00:00.0  2017-07-31 23:59:00.0            587140
#
#       numtotals      perct
# 9296   13191594  53.232778
# 9273   13191594  34.992754
# 9038   13191594   4.450865
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6845ec43-ef5d-4da2-97e5-11bcabc30e02">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d49d35c9-571c-4d48-a339-49994f163f52"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d49d35c9-571c-4d48-a339-49994f163f52");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d49d35c9-571c-4d48-a339-49994f163f52");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd49d35c9-571c-4d48-a339-49994f163f52' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"405a2b33-9914-43f7-bbe1-6a2d654ccdc4":{"roots":{"references":[{"attributes":{},"id":"ef266377-18aa-4289-800a-c4da2d113263","type":"BasicTicker"},{"attributes":{"data_source":{"id":"c9e48b42-7247-4dbf-836f-1807b143df98","type":"ColumnDataSource"},"glyph":{"id":"a4582c91-4ca4-4927-88e8-4998fdb0120d","type":"Text"},"hover_glyph":null,"muted_glyph":null},"id":"108cfc4e-3567-4079-83e9-eb0d12d098d9","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["end","level","start","values","inners","outers","centers","color","devicename_countryname"],"data":{"centers":{"__ndarray__":"AAAAAAAA8j8AAAAAAADyPwAAAAAAAPI/AAAAAAAAAkAAAAAAAAACQAAAAAAAAAJA","dtype":"float64","shape":[6]},"color":["#f22c40","#5ab738","#407ee7","#f22c40","#5ab738","#407ee7"],"devicename_countryname":[["Desktop and Laptop",""],["Mobile",""],["Tablet",""],["Desktop and Laptop","United States"],["Mobile","United States"],["Tablet","United States"]],"end":{"__ndarray__":"M5TWha/6AkDayu7y++wXQBgtRFT7IRlAM5TWha/6AkDayu7y++wXQBgtRFT7IRlA","dtype":"float64","shape":[6]},"inners":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA+D8AAAAAAAD4PwAAAAAAAPg/","dtype":"float64","shape":[6]},"level":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA/","dtype":"float64","shape":[6]},"outers":{"__ndarray__":"AAAAAAAA+D8AAAAAAAD4PwAAAAAAAPg/AAAAAAAACEAAAAAAAAAIQAAAAAAAAAhA","dtype":"float64","shape":[6]},"start":{"__ndarray__":"AAAAAAAAAAAzlNaFr/oCQNrK7vL77BdAAAAAAAAAAAAzlNaFr/oCQNrK7vL77BdA","dtype":"float64","shape":[6]},"values":[4616102,7022252,587140,4616102,7022252,587140]}},"id":"5523d245-dd1c-41f4-aec9-e923741e811e","type":"ColumnDataSource"},{"attributes":{},"id":"40394933-a818-48d7-813d-6e072c14b427","type":"BasicTicker"},{"attributes":{"callback":null,"plot":{"id":"daa374a9-ec00-4b33-a92b-a75701ae5a8d","subtype":"Chart","type":"Plot"},"tooltips":[["Totalimpressions","@values"]]},"id":"197f943d-f231-416a-9dfe-312432919bed","type":"HoverTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"046218c9-a1bd-4551-8d45-5dd425967896","type":"BoxAnnotation"},{"attributes":{},"id":"d6f9305c-61ed-41d5-aa61-77e3a5eb0e08","type":"LinearScale"},{"attributes":{"axis_label":null,"formatter":{"id":"3bbca994-b5a9-4560-92cb-57042a6e7aa6","type":"BasicTickFormatter"},"plot":{"id":"daa374a9-ec00-4b33-a92b-a75701ae5a8d","subtype":"Chart","type":"Plot"},"ticker":{"id":"ef266377-18aa-4289-800a-c4da2d113263","type":"BasicTicker"},"visible":false},"id":"ec04dce5-438b-4a16-bd9f-f0a2c2828bdb","type":"LinearAxis"},{"attributes":{"plot":{"id":"daa374a9-ec00-4b33-a92b-a75701ae5a8d","subtype":"Chart","type":"Plot"}},"id":"d10dd28f-52b2-4ba3-a092-372770646bf6","type":"PanTool"},{"attributes":{},"id":"8f20b83f-8e10-404d-9631-444f42c6cb9f","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"daa374a9-ec00-4b33-a92b-a75701ae5a8d","subtype":"Chart","type":"Plot"}},"id":"af2a0c78-8ed4-4c6e-9b4d-df57a29c740e","type":"ResetTool"},{"attributes":{"axis_label":null,"formatter":{"id":"8f20b83f-8e10-404d-9631-444f42c6cb9f","type":"BasicTickFormatter"},"plot":{"id":"daa374a9-ec00-4b33-a92b-a75701ae5a8d","subtype":"Chart","type":"Plot"},"ticker":{"id":"40394933-a818-48d7-813d-6e072c14b427","type":"BasicTicker"},"visible":false},"id":"7232e49d-0ffd-4f4d-b249-937ee813d0b8","type":"LinearAxis"},{"attributes":{"angle":{"field":"text_angle","units":"rad"},"text_align":"center","text_baseline":"middle","text_font_size":{"value":"10pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a4582c91-4ca4-4927-88e8-4998fdb0120d","type":"Text"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d10dd28f-52b2-4ba3-a092 ...

# %%
rs.close()
